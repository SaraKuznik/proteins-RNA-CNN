# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics

import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 100] = 0
                Y_batch_[Y_batch_ >= 100] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
        

    else:
        X_train.extend(protein[:, :, :, :, :3])
        Y_train.extend(rna)
        num_aa_train +=len(rna)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 100] = 0
Y_test_[Y_test_ >= 100] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400) 
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.6)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=500, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_new')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_new')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_ = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_.shape)


#CNN
Y_pred_prob = Y_pred_
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# (147006, 14, 14, 17)
# 319356 147006
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 14, 14, 17, 3)     0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/500
# 798/798 [==============================] - 247s 310ms/step - loss: 0.5736 - acc: 0.8069 - mean_squared_error: 0.1925 - val_loss: 0.5926 - val_acc: 0.9105 - val_mean_squared_error: 0.2000
# Epoch 2/500
# 798/798 [==============================] - 255s 319ms/step - loss: 0.3874 - acc: 0.9210 - mean_squared_error: 0.1093 - val_loss: 0.4948 - val_acc: 0.9105 - val_mean_squared_error: 0.1532
# Epoch 3/500
# 798/798 [==============================] - 237s 296ms/step - loss: 0.3101 - acc: 0.9226 - mean_squared_error: 0.0817 - val_loss: 0.3818 - val_acc: 0.9105 - val_mean_squared_error: 0.1055
# Epoch 4/500
# 798/798 [==============================] - 243s 305ms/step - loss: 0.2617 - acc: 0.9222 - mean_squared_error: 0.0679 - val_loss: 0.2950 - val_acc: 0.9105 - val_mean_squared_error: 0.0767
# Epoch 5/500
# 798/798 [==============================] - 239s 299ms/step - loss: 0.2281 - acc: 0.9224 - mean_squared_error: 0.0599 - val_loss: 0.2597 - val_acc: 0.9103 - val_mean_squared_error: 0.0680
# Epoch 6/500
# 798/798 [==============================] - 242s 303ms/step - loss: 0.2074 - acc: 0.9224 - mean_squared_error: 0.0561 - val_loss: 0.2321 - val_acc: 0.9105 - val_mean_squared_error: 0.0628
# Epoch 7/500
# 798/798 [==============================] - 236s 296ms/step - loss: 0.1930 - acc: 0.9226 - mean_squared_error: 0.0537 - val_loss: 0.2141 - val_acc: 0.9103 - val_mean_squared_error: 0.0602
# Epoch 8/500
# 798/798 [==============================] - 247s 310ms/step - loss: 0.1826 - acc: 0.9232 - mean_squared_error: 0.0521 - val_loss: 0.2033 - val_acc: 0.9101 - val_mean_squared_error: 0.0590
# Epoch 9/500
# 798/798 [==============================] - 238s 298ms/step - loss: 0.1744 - acc: 0.9250 - mean_squared_error: 0.0505 - val_loss: 0.1979 - val_acc: 0.9103 - val_mean_squared_error: 0.0586
# Epoch 10/500
# 798/798 [==============================] - 246s 309ms/step - loss: 0.1702 - acc: 0.9242 - mean_squared_error: 0.0503 - val_loss: 0.1931 - val_acc: 0.9102 - val_mean_squared_error: 0.0583
# Epoch 11/500
# 798/798 [==============================] - 239s 299ms/step - loss: 0.1658 - acc: 0.9248 - mean_squared_error: 0.0495 - val_loss: 0.1903 - val_acc: 0.9097 - val_mean_squared_error: 0.0581
# Epoch 12/500
# 798/798 [==============================] - 252s 316ms/step - loss: 0.1618 - acc: 0.9261 - mean_squared_error: 0.0486 - val_loss: 0.1880 - val_acc: 0.9096 - val_mean_squared_error: 0.0580
# Epoch 13/500
# 798/798 [==============================] - 238s 298ms/step - loss: 0.1597 - acc: 0.9263 - mean_squared_error: 0.0482 - val_loss: 0.1854 - val_acc: 0.9091 - val_mean_squared_error: 0.0579
# Epoch 14/500
# 798/798 [==============================] - 252s 316ms/step - loss: 0.1567 - acc: 0.9275 - mean_squared_error: 0.0474 - val_loss: 0.1841 - val_acc: 0.9087 - val_mean_squared_error: 0.0580
# Epoch 15/500
# 798/798 [==============================] - 234s 294ms/step - loss: 0.1543 - acc: 0.9285 - mean_squared_error: 0.0467 - val_loss: 0.1844 - val_acc: 0.9083 - val_mean_squared_error: 0.0585
# Epoch 16/500
# 798/798 [==============================] - 254s 318ms/step - loss: 0.1518 - acc: 0.9300 - mean_squared_error: 0.0460 - val_loss: 0.1827 - val_acc: 0.9105 - val_mean_squared_error: 0.0580
# Epoch 17/500
# 798/798 [==============================] - 233s 292ms/step - loss: 0.1493 - acc: 0.9316 - mean_squared_error: 0.0452 - val_loss: 0.1836 - val_acc: 0.9103 - val_mean_squared_error: 0.0582
# Epoch 18/500
# 798/798 [==============================] - 255s 319ms/step - loss: 0.1484 - acc: 0.9318 - mean_squared_error: 0.0449 - val_loss: 0.1858 - val_acc: 0.9088 - val_mean_squared_error: 0.0590
# Epoch 19/500
# 798/798 [==============================] - 232s 291ms/step - loss: 0.1463 - acc: 0.9333 - mean_squared_error: 0.0443 - val_loss: 0.1858 - val_acc: 0.9096 - val_mean_squared_error: 0.0589
# Epoch 20/500
# 798/798 [==============================] - 261s 327ms/step - loss: 0.1445 - acc: 0.9341 - mean_squared_error: 0.0437 - val_loss: 0.1857 - val_acc: 0.9104 - val_mean_squared_error: 0.0586
# Epoch 21/500
# 798/798 [==============================] - 230s 288ms/step - loss: 0.1425 - acc: 0.9360 - mean_squared_error: 0.0430 - val_loss: 0.1856 - val_acc: 0.9115 - val_mean_squared_error: 0.0583
# Epoch 22/500
# 798/798 [==============================] - 258s 323ms/step - loss: 0.1401 - acc: 0.9378 - mean_squared_error: 0.0421 - val_loss: 0.1855 - val_acc: 0.9120 - val_mean_squared_error: 0.0582
# Epoch 23/500
# 798/798 [==============================] - 229s 287ms/step - loss: 0.1386 - acc: 0.9386 - mean_squared_error: 0.0417 - val_loss: 0.1854 - val_acc: 0.9124 - val_mean_squared_error: 0.0580
# Epoch 24/500
# 798/798 [==============================] - 259s 325ms/step - loss: 0.1369 - acc: 0.9399 - mean_squared_error: 0.0410 - val_loss: 0.1853 - val_acc: 0.9127 - val_mean_squared_error: 0.0580
# Epoch 25/500
# 798/798 [==============================] - 229s 287ms/step - loss: 0.1351 - acc: 0.9409 - mean_squared_error: 0.0405 - val_loss: 0.1854 - val_acc: 0.9131 - val_mean_squared_error: 0.0580
# Epoch 26/500
# 798/798 [==============================] - 261s 327ms/step - loss: 0.1331 - acc: 0.9428 - mean_squared_error: 0.0397 - val_loss: 0.1849 - val_acc: 0.9137 - val_mean_squared_error: 0.0579
# Epoch 27/500
# 798/798 [==============================] - 229s 287ms/step - loss: 0.1316 - acc: 0.9436 - mean_squared_error: 0.0392 - val_loss: 0.1855 - val_acc: 0.9132 - val_mean_squared_error: 0.0581
# Epoch 28/500
# 798/798 [==============================] - 262s 328ms/step - loss: 0.1299 - acc: 0.9446 - mean_squared_error: 0.0386 - val_loss: 0.1836 - val_acc: 0.9146 - val_mean_squared_error: 0.0575
# Epoch 29/500
# 798/798 [==============================] - 226s 283ms/step - loss: 0.1262 - acc: 0.9466 - mean_squared_error: 0.0375 - val_loss: 0.1841 - val_acc: 0.9141 - val_mean_squared_error: 0.0577
# Epoch 30/500
# 798/798 [==============================] - 273s 343ms/step - loss: 0.1261 - acc: 0.9476 - mean_squared_error: 0.0372 - val_loss: 0.1872 - val_acc: 0.9116 - val_mean_squared_error: 0.0590
# Epoch 31/500
# 798/798 [==============================] - 226s 283ms/step - loss: 0.1243 - acc: 0.9492 - mean_squared_error: 0.0365 - val_loss: 0.1877 - val_acc: 0.9105 - val_mean_squared_error: 0.0594
# Epoch 32/500
# 798/798 [==============================] - 263s 330ms/step - loss: 0.1226 - acc: 0.9499 - mean_squared_error: 0.0359 - val_loss: 0.1875 - val_acc: 0.9102 - val_mean_squared_error: 0.0594
# Epoch 33/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1202 - acc: 0.9517 - mean_squared_error: 0.0351 - val_loss: 0.1885 - val_acc: 0.9090 - val_mean_squared_error: 0.0600
# Epoch 34/500
# 798/798 [==============================] - 261s 327ms/step - loss: 0.1187 - acc: 0.9526 - mean_squared_error: 0.0345 - val_loss: 0.1921 - val_acc: 0.9068 - val_mean_squared_error: 0.0614
# Epoch 35/500
# 798/798 [==============================] - 222s 278ms/step - loss: 0.1172 - acc: 0.9541 - mean_squared_error: 0.0339 - val_loss: 0.1939 - val_acc: 0.9051 - val_mean_squared_error: 0.0622
# Epoch 36/500
# 798/798 [==============================] - 273s 342ms/step - loss: 0.1152 - acc: 0.9552 - mean_squared_error: 0.0332 - val_loss: 0.1971 - val_acc: 0.9032 - val_mean_squared_error: 0.0633
# Epoch 37/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.1131 - acc: 0.9566 - mean_squared_error: 0.0326 - val_loss: 0.2009 - val_acc: 0.9009 - val_mean_squared_error: 0.0646
# Epoch 38/500
# 798/798 [==============================] - 270s 338ms/step - loss: 0.1115 - acc: 0.9576 - mean_squared_error: 0.0319 - val_loss: 0.2028 - val_acc: 0.9001 - val_mean_squared_error: 0.0653
# Epoch 39/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1101 - acc: 0.9587 - mean_squared_error: 0.0313 - val_loss: 0.2059 - val_acc: 0.8995 - val_mean_squared_error: 0.0660
# Epoch 40/500
# 798/798 [==============================] - 272s 341ms/step - loss: 0.1078 - acc: 0.9601 - mean_squared_error: 0.0305 - val_loss: 0.2054 - val_acc: 0.9002 - val_mean_squared_error: 0.0658
# Epoch 41/500
# 798/798 [==============================] - 219s 275ms/step - loss: 0.1058 - acc: 0.9618 - mean_squared_error: 0.0298 - val_loss: 0.2097 - val_acc: 0.8989 - val_mean_squared_error: 0.0670
# Epoch 42/500
# 798/798 [==============================] - 270s 339ms/step - loss: 0.1047 - acc: 0.9619 - mean_squared_error: 0.0294 - val_loss: 0.2107 - val_acc: 0.8983 - val_mean_squared_error: 0.0673
# Epoch 43/500
# 798/798 [==============================] - 218s 273ms/step - loss: 0.1035 - acc: 0.9628 - mean_squared_error: 0.0290 - val_loss: 0.2125 - val_acc: 0.8980 - val_mean_squared_error: 0.0678
# Epoch 44/500
# 798/798 [==============================] - 275s 345ms/step - loss: 0.1020 - acc: 0.9636 - mean_squared_error: 0.0284 - val_loss: 0.2141 - val_acc: 0.8975 - val_mean_squared_error: 0.0683
# Epoch 45/500
# 798/798 [==============================] - 219s 274ms/step - loss: 0.1002 - acc: 0.9650 - mean_squared_error: 0.0278 - val_loss: 0.2166 - val_acc: 0.8971 - val_mean_squared_error: 0.0689
# Epoch 46/500
# 798/798 [==============================] - 278s 348ms/step - loss: 0.0986 - acc: 0.9657 - mean_squared_error: 0.0272 - val_loss: 0.2179 - val_acc: 0.8969 - val_mean_squared_error: 0.0693
# Epoch 47/500
# 798/798 [==============================] - 218s 274ms/step - loss: 0.0964 - acc: 0.9668 - mean_squared_error: 0.0265 - val_loss: 0.2197 - val_acc: 0.8966 - val_mean_squared_error: 0.0697
# Epoch 48/500
# 798/798 [==============================] - 277s 347ms/step - loss: 0.0949 - acc: 0.9677 - mean_squared_error: 0.0260 - val_loss: 0.2261 - val_acc: 0.8950 - val_mean_squared_error: 0.0714
# Epoch 49/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0936 - acc: 0.9684 - mean_squared_error: 0.0255 - val_loss: 0.2285 - val_acc: 0.8947 - val_mean_squared_error: 0.0719
# Epoch 50/500
# 798/798 [==============================] - 272s 341ms/step - loss: 0.0917 - acc: 0.9695 - mean_squared_error: 0.0249 - val_loss: 0.2361 - val_acc: 0.8933 - val_mean_squared_error: 0.0737
# Epoch 51/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0898 - acc: 0.9703 - mean_squared_error: 0.0242 - val_loss: 0.2417 - val_acc: 0.8920 - val_mean_squared_error: 0.0749
# Epoch 52/500
# 798/798 [==============================] - 274s 343ms/step - loss: 0.0889 - acc: 0.9707 - mean_squared_error: 0.0239 - val_loss: 0.2442 - val_acc: 0.8925 - val_mean_squared_error: 0.0752
# Epoch 53/500
# 798/798 [==============================] - 215s 269ms/step - loss: 0.0874 - acc: 0.9716 - mean_squared_error: 0.0233 - val_loss: 0.2453 - val_acc: 0.8924 - val_mean_squared_error: 0.0753
# Epoch 54/500
# 798/798 [==============================] - 269s 338ms/step - loss: 0.0865 - acc: 0.9717 - mean_squared_error: 0.0231 - val_loss: 0.2484 - val_acc: 0.8923 - val_mean_squared_error: 0.0759
# Epoch 55/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0847 - acc: 0.9729 - mean_squared_error: 0.0225 - val_loss: 0.2487 - val_acc: 0.8929 - val_mean_squared_error: 0.0757
# Epoch 56/500
# 798/798 [==============================] - 282s 353ms/step - loss: 0.0832 - acc: 0.9735 - mean_squared_error: 0.0219 - val_loss: 0.2495 - val_acc: 0.8928 - val_mean_squared_error: 0.0758
# Epoch 57/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0822 - acc: 0.9741 - mean_squared_error: 0.0216 - val_loss: 0.2481 - val_acc: 0.8947 - val_mean_squared_error: 0.0750
# Epoch 58/500
# 798/798 [==============================] - 281s 353ms/step - loss: 0.0806 - acc: 0.9748 - mean_squared_error: 0.0211 - val_loss: 0.2482 - val_acc: 0.8952 - val_mean_squared_error: 0.0748
# Epoch 59/500
# 798/798 [==============================] - 216s 270ms/step - loss: 0.0791 - acc: 0.9755 - mean_squared_error: 0.0206 - val_loss: 0.2515 - val_acc: 0.8949 - val_mean_squared_error: 0.0754
# Epoch 60/500
# 798/798 [==============================] - 284s 356ms/step - loss: 0.0781 - acc: 0.9757 - mean_squared_error: 0.0203 - val_loss: 0.2527 - val_acc: 0.8951 - val_mean_squared_error: 0.0755
# Epoch 61/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0768 - acc: 0.9763 - mean_squared_error: 0.0199 - val_loss: 0.2534 - val_acc: 0.8956 - val_mean_squared_error: 0.0754
# Epoch 62/500
# 798/798 [==============================] - 279s 349ms/step - loss: 0.0753 - acc: 0.9769 - mean_squared_error: 0.0195 - val_loss: 0.2545 - val_acc: 0.8954 - val_mean_squared_error: 0.0756
# Epoch 63/500
# 798/798 [==============================] - 216s 270ms/step - loss: 0.0744 - acc: 0.9774 - mean_squared_error: 0.0191 - val_loss: 0.2560 - val_acc: 0.8960 - val_mean_squared_error: 0.0756
# Epoch 64/500
# 798/798 [==============================] - 281s 353ms/step - loss: 0.0732 - acc: 0.9778 - mean_squared_error: 0.0188 - val_loss: 0.2586 - val_acc: 0.8962 - val_mean_squared_error: 0.0758
# Epoch 65/500
# 798/798 [==============================] - 216s 271ms/step - loss: 0.0721 - acc: 0.9784 - mean_squared_error: 0.0184 - val_loss: 0.2574 - val_acc: 0.8966 - val_mean_squared_error: 0.0755
# Epoch 66/500
# 798/798 [==============================] - 286s 358ms/step - loss: 0.0708 - acc: 0.9786 - mean_squared_error: 0.0181 - val_loss: 0.2612 - val_acc: 0.8961 - val_mean_squared_error: 0.0761
# (146800, 1)
# (146800, 1)
# (147006,)
# CNN:
#
# [[121553  12104]
#  [  3374   9769]] 0.89 0.83
#
#  BASELINE MODEL:
#
# [[133657      0]
#  [ 13143      0]] 0.91 0.5
#
#  RANDOM MODEL:
#
# [[66551 67106]
#  [ 6583  6560]] 0.5 0.5
