# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics


import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 10] = 0
                Y_batch_[Y_batch_ >= 10] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
    
    else:
        protein_1 = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
        rna_1 = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')
        protein_2 = np.load('../data/voxelized data 14x14x17 2 aug/' + structure_id + '_protein.npy')
        rna_2 = np.load('../data/voxelized data 14x14x17 2 aug/' + structure_id + '_rna_3D.npy')

        
        use = []
        for k_1 in range(len(rna_1)):
            if np.sum(rna_1[k_1]) >= 10 or np.sum(rna_1[k_1]) == 0:
                use.append(k_1)
        for k_2 in range(len(rna_2)):
            if np.sum(rna_2[k_2]) >= 10 or np.sum(rna_2[k_2]) == 0:
                use.append(k_2)
        
        
        X_train.extend(protein[use, :, :, :, :3])
        Y_train.extend(rna[use])
        num_aa_train +=len(use)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 10] = 0
Y_test_[Y_test_ >= 10] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400)
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.4)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')
class_weights = {0: 1, 1: 9}

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=1000, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], class_weight=class_weights, verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_1_all')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_1_all')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_prob = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_prob.shape)

#CNN
Y_pred_ = np.copy(Y_pred_prob)
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y_test_, Y_pred_prob)
our_thr = np.where(np.round(thresholds, 2) == 0.5)[0]
roc_auc = sklearn.metrics.auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.plot(fpr[our_thr], tpr[our_thr])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.savefig('roc_curve_w_2')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==1)[0]], bins=100)
plt.savefig('positive_hist_w_2')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==0)[0]], bins=100)
plt.savefig('negative_hist_w_2')
plt.show()

precision, recall, _ = sklearn.metrics.precision_recall_curve(Y_test_, Y_pred_prob)
# calculate F1 score
f1 = sklearn.metrics.f1_score(Y_test_, Y_pred_)
# calculate precision-recall AUC
pr_auc = sklearn.metrics.auc(recall, precision)
# calculate average precision score
ap = sklearn.metrics.average_precision_score(Y_test_, Y_pred_prob)

plt.plot([0, 1], [0.1, 0.1], linestyle='--')
plt.plot(recall, precision, label='f1=%.3f auc=%.3f ap=%.3f' % (f1, pr_auc, ap))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.legend(loc="lower right")
plt.show()


# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# WARNING: Logging before flag parsing goes to stderr.
# W1011 17:50:41.000162 140556681594624 deprecation.py:506] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# (114855, 14, 14, 17)
# 468109 114855
# W1011 17:50:41.466264 140556681594624 deprecation.py:323] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 14, 14, 17, 3)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.4283 - acc: 0.2882 - mean_squared_error: 0.2707 - val_loss: 0.8303 - val_acc: 0.1626 - val_mean_squared_error: 0.3171
# Epoch 2/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.3693 - acc: 0.3974 - mean_squared_error: 0.2814 - val_loss: 0.8525 - val_acc: 0.2924 - val_mean_squared_error: 0.3261
# Epoch 3/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.3348 - acc: 0.4445 - mean_squared_error: 0.2770 - val_loss: 0.8743 - val_acc: 0.3005 - val_mean_squared_error: 0.3355
# Epoch 4/1000
# 1170/1170 [==============================] - 383s 327ms/step - loss: 1.3106 - acc: 0.4475 - mean_squared_error: 0.2744 - val_loss: 0.8843 - val_acc: 0.3063 - val_mean_squared_error: 0.3395
# Epoch 5/1000
# 1170/1170 [==============================] - 383s 327ms/step - loss: 1.2871 - acc: 0.4520 - mean_squared_error: 0.2708 - val_loss: 0.8861 - val_acc: 0.3127 - val_mean_squared_error: 0.3399
# Epoch 6/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.2674 - acc: 0.4618 - mean_squared_error: 0.2668 - val_loss: 0.8675 - val_acc: 0.3385 - val_mean_squared_error: 0.3308
# Epoch 7/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.2492 - acc: 0.4718 - mean_squared_error: 0.2635 - val_loss: 0.8554 - val_acc: 0.3506 - val_mean_squared_error: 0.3250
# Epoch 8/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.2308 - acc: 0.4833 - mean_squared_error: 0.2604 - val_loss: 0.8416 - val_acc: 0.3626 - val_mean_squared_error: 0.3186
# Epoch 9/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.2160 - acc: 0.4954 - mean_squared_error: 0.2571 - val_loss: 0.8381 - val_acc: 0.3659 - val_mean_squared_error: 0.3168
# Epoch 10/1000
# 1170/1170 [==============================] - 383s 327ms/step - loss: 1.2009 - acc: 0.5088 - mean_squared_error: 0.2542 - val_loss: 0.8384 - val_acc: 0.3679 - val_mean_squared_error: 0.3168
# Epoch 11/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.1869 - acc: 0.5222 - mean_squared_error: 0.2509 - val_loss: 0.8341 - val_acc: 0.3752 - val_mean_squared_error: 0.3145
# Epoch 12/1000
# 1170/1170 [==============================] - 383s 328ms/step - loss: 1.1727 - acc: 0.5351 - mean_squared_error: 0.2477 - val_loss: 0.8301 - val_acc: 0.3825 - val_mean_squared_error: 0.3126
# Epoch 13/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.1587 - acc: 0.5479 - mean_squared_error: 0.2445 - val_loss: 0.8247 - val_acc: 0.3962 - val_mean_squared_error: 0.3096
# Epoch 14/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.1449 - acc: 0.5607 - mean_squared_error: 0.2411 - val_loss: 0.8236 - val_acc: 0.4028 - val_mean_squared_error: 0.3088
# Epoch 15/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.1324 - acc: 0.5723 - mean_squared_error: 0.2379 - val_loss: 0.8079 - val_acc: 0.4213 - val_mean_squared_error: 0.3017
# Epoch 16/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.1190 - acc: 0.5849 - mean_squared_error: 0.2347 - val_loss: 0.8167 - val_acc: 0.4224 - val_mean_squared_error: 0.3050
# Epoch 17/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.1061 - acc: 0.5962 - mean_squared_error: 0.2313 - val_loss: 0.8184 - val_acc: 0.4272 - val_mean_squared_error: 0.3053
# Epoch 18/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.0934 - acc: 0.6072 - mean_squared_error: 0.2282 - val_loss: 0.8043 - val_acc: 0.4461 - val_mean_squared_error: 0.2987
# Epoch 19/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.0812 - acc: 0.6176 - mean_squared_error: 0.2249 - val_loss: 0.7910 - val_acc: 0.4623 - val_mean_squared_error: 0.2927
# Epoch 20/1000
# 1170/1170 [==============================] - 384s 328ms/step - loss: 1.0687 - acc: 0.6268 - mean_squared_error: 0.2217 - val_loss: 0.7697 - val_acc: 0.4841 - val_mean_squared_error: 0.2834
# Epoch 21/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.0577 - acc: 0.6362 - mean_squared_error: 0.2186 - val_loss: 0.7572 - val_acc: 0.4987 - val_mean_squared_error: 0.2777
# Epoch 22/1000
# 1170/1170 [==============================] - 384s 329ms/step - loss: 1.0459 - acc: 0.6452 - mean_squared_error: 0.2156 - val_loss: 0.7466 - val_acc: 0.5114 - val_mean_squared_error: 0.2730
# Epoch 23/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.0339 - acc: 0.6518 - mean_squared_error: 0.2130 - val_loss: 0.7231 - val_acc: 0.5348 - val_mean_squared_error: 0.2628
# Epoch 24/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.0233 - acc: 0.6597 - mean_squared_error: 0.2100 - val_loss: 0.6940 - val_acc: 0.5648 - val_mean_squared_error: 0.2501
# Epoch 25/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.0119 - acc: 0.6670 - mean_squared_error: 0.2071 - val_loss: 0.6855 - val_acc: 0.5771 - val_mean_squared_error: 0.2462
# Epoch 26/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 1.0005 - acc: 0.6756 - mean_squared_error: 0.2037 - val_loss: 0.6627 - val_acc: 0.5987 - val_mean_squared_error: 0.2363
# Epoch 27/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9896 - acc: 0.6819 - mean_squared_error: 0.2009 - val_loss: 0.6606 - val_acc: 0.6036 - val_mean_squared_error: 0.2352
# Epoch 28/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9771 - acc: 0.6881 - mean_squared_error: 0.1981 - val_loss: 0.6305 - val_acc: 0.6335 - val_mean_squared_error: 0.2222
# Epoch 29/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9668 - acc: 0.6951 - mean_squared_error: 0.1953 - val_loss: 0.6033 - val_acc: 0.6611 - val_mean_squared_error: 0.2103
# Epoch 30/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9558 - acc: 0.7018 - mean_squared_error: 0.1924 - val_loss: 0.5758 - val_acc: 0.6879 - val_mean_squared_error: 0.1984
# Epoch 31/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9449 - acc: 0.7077 - mean_squared_error: 0.1896 - val_loss: 0.5651 - val_acc: 0.6980 - val_mean_squared_error: 0.1938
# Epoch 32/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9350 - acc: 0.7135 - mean_squared_error: 0.1869 - val_loss: 0.5499 - val_acc: 0.7119 - val_mean_squared_error: 0.1873
# Epoch 33/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9252 - acc: 0.7183 - mean_squared_error: 0.1845 - val_loss: 0.5480 - val_acc: 0.7129 - val_mean_squared_error: 0.1866
# Epoch 34/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9155 - acc: 0.7233 - mean_squared_error: 0.1819 - val_loss: 0.5329 - val_acc: 0.7263 - val_mean_squared_error: 0.1802
# Epoch 35/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.9045 - acc: 0.7288 - mean_squared_error: 0.1794 - val_loss: 0.5228 - val_acc: 0.7353 - val_mean_squared_error: 0.1760
# Epoch 36/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.8953 - acc: 0.7333 - mean_squared_error: 0.1769 - val_loss: 0.5249 - val_acc: 0.7330 - val_mean_squared_error: 0.1770
# Epoch 37/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.8860 - acc: 0.7372 - mean_squared_error: 0.1747 - val_loss: 0.5154 - val_acc: 0.7413 - val_mean_squared_error: 0.1729
# Epoch 38/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8773 - acc: 0.7417 - mean_squared_error: 0.1725 - val_loss: 0.5162 - val_acc: 0.7409 - val_mean_squared_error: 0.1733
# Epoch 39/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.8683 - acc: 0.7458 - mean_squared_error: 0.1704 - val_loss: 0.5208 - val_acc: 0.7376 - val_mean_squared_error: 0.1751
# Epoch 40/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.8585 - acc: 0.7500 - mean_squared_error: 0.1682 - val_loss: 0.5208 - val_acc: 0.7376 - val_mean_squared_error: 0.1750
# Epoch 41/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8496 - acc: 0.7543 - mean_squared_error: 0.1659 - val_loss: 0.5162 - val_acc: 0.7411 - val_mean_squared_error: 0.1732
# Epoch 42/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8407 - acc: 0.7581 - mean_squared_error: 0.1638 - val_loss: 0.5132 - val_acc: 0.7440 - val_mean_squared_error: 0.1719
# Epoch 43/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8315 - acc: 0.7619 - mean_squared_error: 0.1617 - val_loss: 0.5101 - val_acc: 0.7464 - val_mean_squared_error: 0.1706
# Epoch 44/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8235 - acc: 0.7652 - mean_squared_error: 0.1598 - val_loss: 0.5257 - val_acc: 0.7349 - val_mean_squared_error: 0.1768
# Epoch 45/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8148 - acc: 0.7684 - mean_squared_error: 0.1578 - val_loss: 0.5228 - val_acc: 0.7371 - val_mean_squared_error: 0.1754
# Epoch 46/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.8073 - acc: 0.7718 - mean_squared_error: 0.1560 - val_loss: 0.5312 - val_acc: 0.7323 - val_mean_squared_error: 0.1786
# Epoch 47/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.7990 - acc: 0.7750 - mean_squared_error: 0.1541 - val_loss: 0.5419 - val_acc: 0.7254 - val_mean_squared_error: 0.1827
# Epoch 48/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7900 - acc: 0.7782 - mean_squared_error: 0.1523 - val_loss: 0.5562 - val_acc: 0.7165 - val_mean_squared_error: 0.1881
# Epoch 49/1000
# 1170/1170 [==============================] - 385s 329ms/step - loss: 0.7829 - acc: 0.7811 - mean_squared_error: 0.1505 - val_loss: 0.5612 - val_acc: 0.7144 - val_mean_squared_error: 0.1898
# Epoch 50/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7749 - acc: 0.7836 - mean_squared_error: 0.1489 - val_loss: 0.5801 - val_acc: 0.7025 - val_mean_squared_error: 0.1968
# Epoch 51/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7661 - acc: 0.7871 - mean_squared_error: 0.1469 - val_loss: 0.5890 - val_acc: 0.6978 - val_mean_squared_error: 0.2000
# Epoch 52/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7587 - acc: 0.7897 - mean_squared_error: 0.1453 - val_loss: 0.6143 - val_acc: 0.6833 - val_mean_squared_error: 0.2091
# Epoch 53/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7504 - acc: 0.7926 - mean_squared_error: 0.1435 - val_loss: 0.6160 - val_acc: 0.6833 - val_mean_squared_error: 0.2094
# Epoch 54/1000
# 1170/1170 [==============================] - 387s 330ms/step - loss: 0.7433 - acc: 0.7952 - mean_squared_error: 0.1421 - val_loss: 0.6300 - val_acc: 0.6766 - val_mean_squared_error: 0.2142
# Epoch 55/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7358 - acc: 0.7983 - mean_squared_error: 0.1404 - val_loss: 0.6498 - val_acc: 0.6670 - val_mean_squared_error: 0.2211
# Epoch 56/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7287 - acc: 0.8005 - mean_squared_error: 0.1391 - val_loss: 0.6461 - val_acc: 0.6710 - val_mean_squared_error: 0.2193
# Epoch 57/1000
# 1170/1170 [==============================] - 387s 330ms/step - loss: 0.7209 - acc: 0.8030 - mean_squared_error: 0.1373 - val_loss: 0.6524 - val_acc: 0.6685 - val_mean_squared_error: 0.2211
# Epoch 58/1000
# 1170/1170 [==============================] - 386s 330ms/step - loss: 0.7142 - acc: 0.8053 - mean_squared_error: 0.1360 - val_loss: 0.6578 - val_acc: 0.6672 - val_mean_squared_error: 0.2226
# Epoch 59/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.7079 - acc: 0.8076 - mean_squared_error: 0.1345 - val_loss: 0.6526 - val_acc: 0.6717 - val_mean_squared_error: 0.2204
# Epoch 60/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.7000 - acc: 0.8102 - mean_squared_error: 0.1330 - val_loss: 0.6358 - val_acc: 0.6826 - val_mean_squared_error: 0.2139
# Epoch 61/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.6930 - acc: 0.8122 - mean_squared_error: 0.1315 - val_loss: 0.6345 - val_acc: 0.6841 - val_mean_squared_error: 0.2132
# Epoch 62/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.6854 - acc: 0.8146 - mean_squared_error: 0.1300 - val_loss: 0.6319 - val_acc: 0.6870 - val_mean_squared_error: 0.2119
# Epoch 63/1000
# 1170/1170 [==============================] - 388s 331ms/step - loss: 0.6778 - acc: 0.8173 - mean_squared_error: 0.1286 - val_loss: 0.6230 - val_acc: 0.6922 - val_mean_squared_error: 0.2084
# Epoch 64/1000
# 1170/1170 [==============================] - 388s 331ms/step - loss: 0.6719 - acc: 0.8189 - mean_squared_error: 0.1274 - val_loss: 0.6161 - val_acc: 0.6979 - val_mean_squared_error: 0.2055
# Epoch 65/1000
# 1170/1170 [==============================] - 387s 330ms/step - loss: 0.6642 - acc: 0.8219 - mean_squared_error: 0.1257 - val_loss: 0.6198 - val_acc: 0.6978 - val_mean_squared_error: 0.2064
# Epoch 66/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.6578 - acc: 0.8235 - mean_squared_error: 0.1246 - val_loss: 0.5969 - val_acc: 0.7111 - val_mean_squared_error: 0.1979
# Epoch 67/1000
# 1170/1170 [==============================] - 387s 331ms/step - loss: 0.6505 - acc: 0.8255 - mean_squared_error: 0.1233 - val_loss: 0.5996 - val_acc: 0.7111 - val_mean_squared_error: 0.1985
# Epoch 68/1000
# 1170/1170 [==============================] - 388s 331ms/step - loss: 0.6427 - acc: 0.8280 - mean_squared_error: 0.1217 - val_loss: 0.5781 - val_acc: 0.7236 - val_mean_squared_error: 0.1906
# Epoch 69/1000
# 1170/1170 [==============================] - 388s 331ms/step - loss: 0.6361 - acc: 0.8302 - mean_squared_error: 0.1205 - val_loss: 0.5760 - val_acc: 0.7258 - val_mean_squared_error: 0.1896
# Epoch 70/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.6294 - acc: 0.8322 - mean_squared_error: 0.1189 - val_loss: 0.5497 - val_acc: 0.7404 - val_mean_squared_error: 0.1802
# Epoch 71/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.6242 - acc: 0.8337 - mean_squared_error: 0.1179 - val_loss: 0.5196 - val_acc: 0.7574 - val_mean_squared_error: 0.1694
# Epoch 72/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.6175 - acc: 0.8361 - mean_squared_error: 0.1167 - val_loss: 0.4949 - val_acc: 0.7712 - val_mean_squared_error: 0.1605
# Epoch 73/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.6093 - acc: 0.8377 - mean_squared_error: 0.1155 - val_loss: 0.4704 - val_acc: 0.7855 - val_mean_squared_error: 0.1516
# Epoch 74/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.6038 - acc: 0.8397 - mean_squared_error: 0.1142 - val_loss: 0.4350 - val_acc: 0.8051 - val_mean_squared_error: 0.1386
# Epoch 75/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.5977 - acc: 0.8420 - mean_squared_error: 0.1127 - val_loss: 0.4223 - val_acc: 0.8131 - val_mean_squared_error: 0.1336
# Epoch 76/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.5922 - acc: 0.8436 - mean_squared_error: 0.1118 - val_loss: 0.4091 - val_acc: 0.8223 - val_mean_squared_error: 0.1284
# Epoch 77/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.5847 - acc: 0.8455 - mean_squared_error: 0.1106 - val_loss: 0.3924 - val_acc: 0.8338 - val_mean_squared_error: 0.1218
# Epoch 78/1000
# 1170/1170 [==============================] - 388s 331ms/step - loss: 0.5772 - acc: 0.8470 - mean_squared_error: 0.1094 - val_loss: 0.3824 - val_acc: 0.8428 - val_mean_squared_error: 0.1171
# Epoch 79/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5719 - acc: 0.8495 - mean_squared_error: 0.1080 - val_loss: 0.3790 - val_acc: 0.8464 - val_mean_squared_error: 0.1153
# Epoch 80/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5665 - acc: 0.8512 - mean_squared_error: 0.1069 - val_loss: 0.3821 - val_acc: 0.8456 - val_mean_squared_error: 0.1162
# Epoch 81/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.5602 - acc: 0.8530 - mean_squared_error: 0.1058 - val_loss: 0.3811 - val_acc: 0.8466 - val_mean_squared_error: 0.1154
# Epoch 82/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5540 - acc: 0.8547 - mean_squared_error: 0.1047 - val_loss: 0.3858 - val_acc: 0.8444 - val_mean_squared_error: 0.1168
# Epoch 83/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5480 - acc: 0.8562 - mean_squared_error: 0.1036 - val_loss: 0.3851 - val_acc: 0.8459 - val_mean_squared_error: 0.1162
# Epoch 84/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5419 - acc: 0.8582 - mean_squared_error: 0.1024 - val_loss: 0.3855 - val_acc: 0.8463 - val_mean_squared_error: 0.1159
# Epoch 85/1000
# 1170/1170 [==============================] - 389s 332ms/step - loss: 0.5356 - acc: 0.8601 - mean_squared_error: 0.1012 - val_loss: 0.3823 - val_acc: 0.8494 - val_mean_squared_error: 0.1142
# Epoch 86/1000
# 1170/1170 [==============================] - 388s 332ms/step - loss: 0.5296 - acc: 0.8617 - mean_squared_error: 0.1001 - val_loss: 0.3830 - val_acc: 0.8496 - val_mean_squared_error: 0.1141
# Epoch 87/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.5233 - acc: 0.8634 - mean_squared_error: 0.0991 - val_loss: 0.3848 - val_acc: 0.8498 - val_mean_squared_error: 0.1141
# Epoch 88/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.5182 - acc: 0.8648 - mean_squared_error: 0.0979 - val_loss: 0.3848 - val_acc: 0.8515 - val_mean_squared_error: 0.1135
# Epoch 89/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.5117 - acc: 0.8665 - mean_squared_error: 0.0968 - val_loss: 0.3838 - val_acc: 0.8536 - val_mean_squared_error: 0.1123
# Epoch 90/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.5055 - acc: 0.8686 - mean_squared_error: 0.0957 - val_loss: 0.3842 - val_acc: 0.8538 - val_mean_squared_error: 0.1122
# Epoch 91/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.5000 - acc: 0.8701 - mean_squared_error: 0.0947 - val_loss: 0.3859 - val_acc: 0.8539 - val_mean_squared_error: 0.1123
# Epoch 92/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4948 - acc: 0.8717 - mean_squared_error: 0.0937 - val_loss: 0.3859 - val_acc: 0.8546 - val_mean_squared_error: 0.1120
# Epoch 93/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4883 - acc: 0.8734 - mean_squared_error: 0.0925 - val_loss: 0.3900 - val_acc: 0.8537 - val_mean_squared_error: 0.1128
# Epoch 94/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4829 - acc: 0.8746 - mean_squared_error: 0.0915 - val_loss: 0.3899 - val_acc: 0.8534 - val_mean_squared_error: 0.1128
# Epoch 95/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4771 - acc: 0.8764 - mean_squared_error: 0.0904 - val_loss: 0.3952 - val_acc: 0.8515 - val_mean_squared_error: 0.1142
# Epoch 96/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4718 - acc: 0.8779 - mean_squared_error: 0.0894 - val_loss: 0.3965 - val_acc: 0.8523 - val_mean_squared_error: 0.1138
# Epoch 97/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4665 - acc: 0.8793 - mean_squared_error: 0.0884 - val_loss: 0.4001 - val_acc: 0.8529 - val_mean_squared_error: 0.1139
# Epoch 98/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4606 - acc: 0.8808 - mean_squared_error: 0.0874 - val_loss: 0.3994 - val_acc: 0.8540 - val_mean_squared_error: 0.1132
# Epoch 99/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4551 - acc: 0.8822 - mean_squared_error: 0.0864 - val_loss: 0.4059 - val_acc: 0.8540 - val_mean_squared_error: 0.1141
# Epoch 100/1000
# 1170/1170 [==============================] - 389s 333ms/step - loss: 0.4501 - acc: 0.8838 - mean_squared_error: 0.0855 - val_loss: 0.4086 - val_acc: 0.8555 - val_mean_squared_error: 0.1137
# Epoch 101/1000
# 1170/1170 [==============================] - 390s 334ms/step - loss: 0.4439 - acc: 0.8857 - mean_squared_error: 0.0843 - val_loss: 0.4116 - val_acc: 0.8561 - val_mean_squared_error: 0.1136
# Epoch 102/1000
# 1170/1170 [==============================] - 390s 334ms/step - loss: 0.4387 - acc: 0.8867 - mean_squared_error: 0.0833 - val_loss: 0.4153 - val_acc: 0.8567 - val_mean_squared_error: 0.1136
# Epoch 103/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4326 - acc: 0.8886 - mean_squared_error: 0.0822 - val_loss: 0.4196 - val_acc: 0.8570 - val_mean_squared_error: 0.1137
# Epoch 104/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.4284 - acc: 0.8901 - mean_squared_error: 0.0814 - val_loss: 0.4213 - val_acc: 0.8578 - val_mean_squared_error: 0.1135
# Epoch 105/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4225 - acc: 0.8912 - mean_squared_error: 0.0803 - val_loss: 0.4253 - val_acc: 0.8570 - val_mean_squared_error: 0.1141
# Epoch 106/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4171 - acc: 0.8929 - mean_squared_error: 0.0794 - val_loss: 0.4262 - val_acc: 0.8587 - val_mean_squared_error: 0.1132
# Epoch 107/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4117 - acc: 0.8945 - mean_squared_error: 0.0783 - val_loss: 0.4309 - val_acc: 0.8586 - val_mean_squared_error: 0.1136
# Epoch 108/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4070 - acc: 0.8955 - mean_squared_error: 0.0775 - val_loss: 0.4326 - val_acc: 0.8582 - val_mean_squared_error: 0.1137
# Epoch 109/1000
# 1170/1170 [==============================] - 390s 333ms/step - loss: 0.4015 - acc: 0.8972 - mean_squared_error: 0.0764 - val_loss: 0.4351 - val_acc: 0.8585 - val_mean_squared_error: 0.1138
# Epoch 110/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3970 - acc: 0.8985 - mean_squared_error: 0.0756 - val_loss: 0.4350 - val_acc: 0.8574 - val_mean_squared_error: 0.1140
# Epoch 111/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3916 - acc: 0.8998 - mean_squared_error: 0.0746 - val_loss: 0.4371 - val_acc: 0.8576 - val_mean_squared_error: 0.1141
# Epoch 112/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3862 - acc: 0.9012 - mean_squared_error: 0.0736 - val_loss: 0.4369 - val_acc: 0.8575 - val_mean_squared_error: 0.1139
# Epoch 113/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3817 - acc: 0.9025 - mean_squared_error: 0.0728 - val_loss: 0.4397 - val_acc: 0.8557 - val_mean_squared_error: 0.1150
# Epoch 114/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3763 - acc: 0.9038 - mean_squared_error: 0.0719 - val_loss: 0.4389 - val_acc: 0.8552 - val_mean_squared_error: 0.1152
# Epoch 115/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3717 - acc: 0.9054 - mean_squared_error: 0.0709 - val_loss: 0.4447 - val_acc: 0.8519 - val_mean_squared_error: 0.1172
# Epoch 116/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3665 - acc: 0.9069 - mean_squared_error: 0.0699 - val_loss: 0.4459 - val_acc: 0.8531 - val_mean_squared_error: 0.1166
# Epoch 117/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3617 - acc: 0.9077 - mean_squared_error: 0.0690 - val_loss: 0.4517 - val_acc: 0.8491 - val_mean_squared_error: 0.1189
# Epoch 118/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3575 - acc: 0.9090 - mean_squared_error: 0.0682 - val_loss: 0.4528 - val_acc: 0.8504 - val_mean_squared_error: 0.1181
# Epoch 119/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3521 - acc: 0.9104 - mean_squared_error: 0.0673 - val_loss: 0.4549 - val_acc: 0.8492 - val_mean_squared_error: 0.1188
# Epoch 120/1000
# 1170/1170 [==============================] - 391s 335ms/step - loss: 0.3479 - acc: 0.9118 - mean_squared_error: 0.0664 - val_loss: 0.4609 - val_acc: 0.8475 - val_mean_squared_error: 0.1202
# Epoch 121/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3431 - acc: 0.9131 - mean_squared_error: 0.0655 - val_loss: 0.4629 - val_acc: 0.8479 - val_mean_squared_error: 0.1200
# Epoch 122/1000
# 1170/1170 [==============================] - 391s 334ms/step - loss: 0.3382 - acc: 0.9143 - mean_squared_error: 0.0647 - val_loss: 0.4663 - val_acc: 0.8486 - val_mean_squared_error: 0.1200
# Epoch 123/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3344 - acc: 0.9152 - mean_squared_error: 0.0639 - val_loss: 0.4714 - val_acc: 0.8461 - val_mean_squared_error: 0.1217
# Epoch 124/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3297 - acc: 0.9166 - mean_squared_error: 0.0630 - val_loss: 0.4750 - val_acc: 0.8448 - val_mean_squared_error: 0.1226
# Epoch 125/1000
# 1170/1170 [==============================] - 391s 335ms/step - loss: 0.3256 - acc: 0.9181 - mean_squared_error: 0.0622 - val_loss: 0.4806 - val_acc: 0.8434 - val_mean_squared_error: 0.1239
# Epoch 126/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3208 - acc: 0.9191 - mean_squared_error: 0.0613 - val_loss: 0.4856 - val_acc: 0.8414 - val_mean_squared_error: 0.1251
# Epoch 127/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3165 - acc: 0.9201 - mean_squared_error: 0.0605 - val_loss: 0.4810 - val_acc: 0.8456 - val_mean_squared_error: 0.1226
# Epoch 128/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3118 - acc: 0.9217 - mean_squared_error: 0.0596 - val_loss: 0.4924 - val_acc: 0.8421 - val_mean_squared_error: 0.1253
# Epoch 129/1000
# 1170/1170 [==============================] - 392s 335ms/step - loss: 0.3073 - acc: 0.9227 - mean_squared_error: 0.0587 - val_loss: 0.4954 - val_acc: 0.8423 - val_mean_squared_error: 0.1252
# (114800, 1)
# (114800, 1)
# (114855,)
# CNN:
#
# [[88938  9737]
#  [ 8388  7737]] 0.84 0.8
#  BASELINE MODEL:
#
# [[98675     0]
#  [16125     0]] 0.86 0.5
#
#  RANDOM MODEL:
#
# [[49211 49464]
#  [ 8074  8051]] 0.5 0.5
