# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('statistics_all.csv', low_memory=False) #[['Aminoacid', 'x size', 'y size', 'z size']]
for name, data in df.groupby('Aminoacid'):
    plt.rcParams['figure.figsize'] = [20, 5]
    f, (ax1, ax2, ax3) = plt.subplots(1, 3)
    f.suptitle(name)
    
    
    x_sizes = data['x size'].values
    ax1.hist(x_sizes, bins=100)
    ax1.set_xlim(right=15)
    ax1.set_xticks(range(0, 16, 1))
    ax1.set_xlabel('x edge length')
    ax1.set_ylabel('Frequency')

    y_sizes = data['y size'].values
    ax2.hist(y_sizes, bins=100)
    ax2.set_xlim(left=0, right=15)
    ax2.set_xticks(range(0, 16, 1))
    ax2.set_xlabel('y edge length')
    ax2.set_ylabel('Frequency')

    z_sizes = data['z size'].values
    ax3.hist(z_sizes, bins=100)
    ax3.set_xlim(right=15)
    ax3.set_xticks(range(0, 16, 1))
    ax3.set_xlabel('z edge length')
    ax3.set_ylabel('Frequency')
    
    plt.show()

    print(f'{name}: mean of x sizes: {np.round(np.mean(x_sizes), 2)}, mean of y sizes: '
          f'{np.round(np.mean(y_sizes), 2)}, mean of z sizes: {np.round(np.mean(z_sizes), 2)}')
    print(f'{name}: max of x sizes: {np.round(np.max(x_sizes), 2)}, max of y sizes: '
          f'{np.round(np.max(y_sizes), 2)}, max of z sizes: {np.round(np.max(z_sizes), 2)}')
# Out:
# ALA: mean of x sizes: 1.92, mean of y sizes: 2.48, mean of z sizes: 2.37
# ALA: max of x sizes: 4.43, max of y sizes: 5.35, max of z sizes: 5.14
# ARG: mean of x sizes: 5.64, mean of y sizes: 4.86, mean of z sizes: 4.93
# ARG: max of x sizes: 16.54, max of y sizes: 73.88, max of z sizes: 17.67
# ASN: mean of x sizes: 3.51, mean of y sizes: 3.54, mean of z sizes: 3.39
# ASN: max of x sizes: 9.15, max of y sizes: 8.87, max of z sizes: 9.07
# ASP: mean of x sizes: 3.46, mean of y sizes: 3.39, mean of z sizes: 3.31
# ASP: max of x sizes: 8.74, max of y sizes: 7.71, max of z sizes: 7.83
# CYS: mean of x sizes: 2.86, mean of y sizes: 2.88, mean of z sizes: 2.87
# CYS: max of x sizes: 7.41, max of y sizes: 6.9, max of z sizes: 7.72
# GLN: mean of x sizes: 4.38, mean of y sizes: 3.87, mean of z sizes: 3.92
# GLN: max of x sizes: 50.0, max of y sizes: 11.75, max of z sizes: 11.56
# GLU: mean of x sizes: 4.21, mean of y sizes: 3.79, mean of z sizes: 3.78
# GLU: max of x sizes: 11.27, max of y sizes: 9.98, max of z sizes: 10.07
# HIS: mean of x sizes: 4.21, mean of y sizes: 4.29, mean of z sizes: 3.92
# HIS: max of x sizes: 11.23, max of y sizes: 11.2, max of z sizes: 11.09
# ILE: mean of x sizes: 3.76, mean of y sizes: 3.52, mean of z sizes: 3.57
# ILE: max of x sizes: 9.43, max of y sizes: 9.3, max of z sizes: 9.36
# LEU: mean of x sizes: 4.12, mean of y sizes: 3.46, mean of z sizes: 3.76
# LEU: max of x sizes: 9.48, max of y sizes: 9.45, max of z sizes: 9.48
# LYS: mean of x sizes: 4.83, mean of y sizes: 4.16, mean of z sizes: 4.33
# LYS: max of x sizes: 15.24, max of y sizes: 13.97, max of z sizes: 14.3
# MET: mean of x sizes: 4.5, mean of y sizes: 3.87, mean of z sizes: 4.16
# MET: max of x sizes: 12.67, max of y sizes: 12.47, max of z sizes: 12.67
# PHE: mean of x sizes: 4.86, mean of y sizes: 4.98, mean of z sizes: 4.56
# PHE: max of x sizes: 12.51, max of y sizes: 12.61, max of z sizes: 12.57
# PRO: mean of x sizes: 2.66, mean of y sizes: 3.26, mean of z sizes: 2.76
# PRO: max of x sizes: 6.36, max of y sizes: 6.71, max of z sizes: 6.69
# SER: mean of x sizes: 2.6, mean of y sizes: 2.76, mean of z sizes: 2.72
# SER: max of x sizes: 6.59, max of y sizes: 6.52, max of z sizes: 6.55
# THR: mean of x sizes: 3.05, mean of y sizes: 3.01, mean of z sizes: 3.04
# THR: max of x sizes: 6.99, max of y sizes: 7.02, max of z sizes: 6.99
# TRP: mean of x sizes: 5.67, mean of y sizes: 5.62, mean of z sizes: 5.19
# TRP: max of x sizes: 15.17, max of y sizes: 14.35, max of z sizes: 14.85
# TYR: mean of x sizes: 5.13, mean of y sizes: 5.63, mean of z sizes: 4.97
# TYR: max of x sizes: 14.23, max of y sizes: 14.0, max of z sizes: 13.87
# VAL: mean of x sizes: 3.03, mean of y sizes: 3.17, mean of z sizes: 3.15
# VAL: max of x sizes: 7.07, max of y sizes: 7.08, max of z sizes: 7.01

# %%
for name, data in df.groupby('Aminoacid'):

    dist = data.loc[data['closest rna above dist.'] != 'None', ['closest rna above dist.', 'closest rna above perp.']].astype(
    float)
    dist_from_plane = dist['closest rna above perp.'].values
    dist_on_plane = (dist['closest rna above dist.'].values ** 2 - dist['closest rna above perp.'].values ** 2) ** (1/2)
    dist_in = data.loc[data['closest rna above in'] == 'True', 'closest rna above perp.'].astype(float).values
    
    dist_below = data.loc[data['closest rna below dist.'] != 'None', ['closest rna below dist.', 
                                                                        'closest rna below perp.']].astype(float)

    dist_on_plane_below = (dist_below['closest rna below dist.'].values ** 2 -
                           dist_below['closest rna below perp.'].values ** 2) ** (1/2)
    
    f2, (ax4, ax5, ax6, ax7) = plt.subplots(1, 4)
    f2.suptitle(name)
    
    ax4.hist(dist_from_plane, bins=100)
    # ax4.set_xlim(left=0, right=50)
    # ax4.set_xticks(range(0, 16, 1))
    ax4.set_xlabel('dist. from plane')
    ax4.set_ylabel('Frequency')
    
    ax5.hist(dist_on_plane, bins=100)
    # ax5.set_xlim(left=0, right=50)
    # ax5.set_xticks(range(0, 16, 1))
    ax5.set_xlabel('dist. from center on plane, rna above plane')
    ax5.set_ylabel('Frequency')
    
    ax6.hist(dist_on_plane_below, bins=100)
    # ax6.set_xlim(left=0, right=50)
    # ax6.set_xticks(range(0, 16, 1))
    ax6.set_xlabel('dist. from center on plane, rna below plane')
    ax6.set_ylabel('Frequency')
    
    ax7.hist(dist_in, bins=100)
    # ax7.set_xlim(left=0, right=50)
    # ax7.set_xticks(range(0, 16, 1))
    ax7.set_xlabel('dist. from plane in box')
    ax7.set_ylabel('Frequency')
    
    plt.show()
    
    print(f'{name}: mean dist. from plane: {np.round(np.mean(dist_from_plane), 2)}, '
          f'mean dist. on plane, rna above plane: {np.round(np.mean(dist_on_plane), 2)}, '
          f'mean dist. on plane, rna below plane: {np.round(np.mean(dist_on_plane_below), 2)},'
          f'mean dist. from plane in box: {np.round(np.mean(dist_in), 2)}')
    print(f'{name}: max dist. from plane: {np.round(np.max(dist_from_plane), 2)}, '
          f'max dist. on plane: {np.round(np.max(dist_on_plane), 2)}, '
          f'max dist. on plane, rna below plane: {np.round(np.max(dist_on_plane_below), 2)},'
          f'max dist. from plane in box: {np.round(np.max(dist_in), 2)}')
    
    rna_in_bb = (data.loc[data['closest rna below in'] == 'True'].shape[0] / data.shape[0]) * 100
    print(f'{name}: {np.round(rna_in_bb, 2)}% rna already in bounding box')
# Out:
# ALA: mean dist. from plane: 11.34, mean dist. on plane, rna above plane: 14.4, mean dist. on plane, rna below plane: 11.58,mean dist. from plane in box: 5.98
# ALA: max dist. from plane: 113.1, max dist. on plane: 151.7, max dist. on plane, rna below plane: 157.16,max dist. from plane in box: 56.87
# ALA: 0.58% rna already in bounding box
# ARG: mean dist. from plane: 10.13, mean dist. on plane, rna above plane: 13.59, mean dist. on plane, rna below plane: 10.3,mean dist. from plane in box: 3.69
# ARG: max dist. from plane: 109.53, max dist. on plane: 153.58, max dist. on plane, rna below plane: 147.9,max dist. from plane in box: 73.0
# ARG: 4.13% rna already in bounding box
# ASN: mean dist. from plane: 13.47, mean dist. on plane, rna above plane: 15.14, mean dist. on plane, rna below plane: 10.88,mean dist. from plane in box: 4.87
# ASN: max dist. from plane: 105.11, max dist. on plane: 145.79, max dist. on plane, rna below plane: 143.49,max dist. from plane in box: 75.35
# ASN: 1.57% rna already in bounding box
# ASP: mean dist. from plane: 14.01, mean dist. on plane, rna above plane: 15.92, mean dist. on plane, rna below plane: 12.28,mean dist. from plane in box: 6.51
# ASP: max dist. from plane: 110.12, max dist. on plane: 153.23, max dist. on plane, rna below plane: 142.75,max dist. from plane in box: 64.83
# ASP: 1.09% rna already in bounding box
# CYS: mean dist. from plane: 14.52, mean dist. on plane, rna above plane: 16.45, mean dist. on plane, rna below plane: 12.42,mean dist. from plane in box: 9.9
# CYS: max dist. from plane: 83.57, max dist. on plane: 113.89, max dist. on plane, rna below plane: 138.08,max dist. from plane in box: 66.95
# CYS: 0.6% rna already in bounding box
# GLN: mean dist. from plane: 13.1, mean dist. on plane, rna above plane: 15.02, mean dist. on plane, rna below plane: 11.48,mean dist. from plane in box: 4.91
# GLN: max dist. from plane: 105.17, max dist. on plane: 140.63, max dist. on plane, rna below plane: 144.16,max dist. from plane in box: 72.52
# GLN: 1.9% rna already in bounding box
# GLU: mean dist. from plane: 13.99, mean dist. on plane, rna above plane: 16.87, mean dist. on plane, rna below plane: 13.78,mean dist. from plane in box: 7.56
# GLU: max dist. from plane: 111.98, max dist. on plane: 159.22, max dist. on plane, rna below plane: 153.83,max dist. from plane in box: 76.27
# GLU: 0.79% rna already in bounding box
# HIS: mean dist. from plane: 11.24, mean dist. on plane, rna above plane: 14.54, mean dist. on plane, rna below plane: 10.19,mean dist. from plane in box: 4.51
# HIS: max dist. from plane: 109.33, max dist. on plane: 152.37, max dist. on plane, rna below plane: 152.49,max dist. from plane in box: 77.01
# HIS: 2.1% rna already in bounding box
# ILE: mean dist. from plane: 13.29, mean dist. on plane, rna above plane: 16.0, mean dist. on plane, rna below plane: 12.71,mean dist. from plane in box: 6.34
# ILE: max dist. from plane: 106.65, max dist. on plane: 151.58, max dist. on plane, rna below plane: 149.62,max dist. from plane in box: 69.88
# ILE: 0.96% rna already in bounding box
# LEU: mean dist. from plane: 13.62, mean dist. on plane, rna above plane: 16.35, mean dist. on plane, rna below plane: 13.25,mean dist. from plane in box: 7.39
# LEU: max dist. from plane: 110.95, max dist. on plane: 151.69, max dist. on plane, rna below plane: 151.69,max dist. from plane in box: 78.3
# LEU: 0.88% rna already in bounding box
# LYS: mean dist. from plane: 11.73, mean dist. on plane, rna above plane: 14.63, mean dist. on plane, rna below plane: 10.79,mean dist. from plane in box: 3.61
# LYS: max dist. from plane: 110.51, max dist. on plane: 151.92, max dist. on plane, rna below plane: 152.75,max dist. from plane in box: 71.8
# LYS: 2.73% rna already in bounding box
# MET: mean dist. from plane: 12.74, mean dist. on plane, rna above plane: 15.46, mean dist. on plane, rna below plane: 12.5,mean dist. from plane in box: 5.89
# MET: max dist. from plane: 104.89, max dist. on plane: 142.97, max dist. on plane, rna below plane: 139.14,max dist. from plane in box: 73.84
# MET: 1.7% rna already in bounding box
# PHE: mean dist. from plane: 12.99, mean dist. on plane, rna above plane: 15.7, mean dist. on plane, rna below plane: 12.5,mean dist. from plane in box: 6.81
# PHE: max dist. from plane: 104.96, max dist. on plane: 154.95, max dist. on plane, rna below plane: 144.27,max dist. from plane in box: 65.89
# PHE: 2.57% rna already in bounding box
# PRO: mean dist. from plane: 12.41, mean dist. on plane, rna above plane: 14.86, mean dist. on plane, rna below plane: 11.49,mean dist. from plane in box: 4.98
# PRO: max dist. from plane: 112.77, max dist. on plane: 149.66, max dist. on plane, rna below plane: 145.18,max dist. from plane in box: 67.24
# PRO: 1.54% rna already in bounding box
# SER: mean dist. from plane: 13.2, mean dist. on plane, rna above plane: 14.88, mean dist. on plane, rna below plane: 11.17,mean dist. from plane in box: 4.92
# SER: max dist. from plane: 104.17, max dist. on plane: 157.04, max dist. on plane, rna below plane: 148.55,max dist. from plane in box: 77.77
# SER: 1.11% rna already in bounding box
# THR: mean dist. from plane: 13.7, mean dist. on plane, rna above plane: 15.08, mean dist. on plane, rna below plane: 11.84,mean dist. from plane in box: 5.94
# THR: max dist. from plane: 104.76, max dist. on plane: 149.77, max dist. on plane, rna below plane: 146.49,max dist. from plane in box: 61.02
# THR: 0.94% rna already in bounding box
# TRP: mean dist. from plane: 12.37, mean dist. on plane, rna above plane: 15.15, mean dist. on plane, rna below plane: 11.41,mean dist. from plane in box: 4.21
# TRP: max dist. from plane: 91.54, max dist. on plane: 144.03, max dist. on plane, rna below plane: 126.12,max dist. from plane in box: 67.29
# TRP: 3.04% rna already in bounding box
# TYR: mean dist. from plane: 11.89, mean dist. on plane, rna above plane: 15.22, mean dist. on plane, rna below plane: 12.4,mean dist. from plane in box: 5.8
# TYR: max dist. from plane: 103.89, max dist. on plane: 152.74, max dist. on plane, rna below plane: 141.58,max dist. from plane in box: 66.9
# TYR: 3.12% rna already in bounding box
# VAL: mean dist. from plane: 12.28, mean dist. on plane, rna above plane: 15.32, mean dist. on plane, rna below plane: 12.37,mean dist. from plane in box: 7.62
# VAL: max dist. from plane: 109.53, max dist. on plane: 153.95, max dist. on plane, rna below plane: 149.71,max dist. from plane in box: 68.71
# VAL: 0.85% rna already in bounding box
