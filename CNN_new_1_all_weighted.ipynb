# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics


import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 10] = 0
                Y_batch_[Y_batch_ >= 10] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
    
    else:
        use = []
        for k in range(len(rna)):
            if np.sum(rna[k]) >= 10 or np.sum(rna[k]) == 0:
                use.append(k)
        
        
        X_train.extend(protein[use, :, :, :, :3])
        Y_train.extend(rna[use])
        num_aa_train +=len(use)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 10] = 0
Y_test_[Y_test_ >= 10] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400) 
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.4)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')
class_weights = {0: 1, 1: 9}

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=1000, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], class_weight=class_weights, verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_1_all')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_1_all')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_prob = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_prob.shape)

#CNN
Y_pred_ = np.copy(Y_pred_prob)
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y_test_, Y_pred_prob)
our_thr = np.where(np.round(thresholds, 2) == 0.5)[0]
roc_auc = sklearn.metrics.auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.plot(fpr[our_thr], tpr[our_thr])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.savefig('roc_curve_w')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==1)[0]], bins=100)
plt.savefig('positive_hist_w')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==0)[0]], bins=100)
plt.savefig('negative_hist_w')
plt.show()

precision, recall, _ = sklearn.metrics.precision_recall_curve(Y_test_, Y_pred_prob)
# calculate F1 score
f1 = sklearn.metrics.f1_score(Y_test_, Y_pred_)
# calculate precision-recall AUC
pr_auc = sklearn.metrics.auc(recall, precision)
# calculate average precision score
ap = sklearn.metrics.average_precision_score(Y_test_, Y_pred_prob)

plt.plot([0, 1], [0.1, 0.1], linestyle='--')
plt.plot(recall, precision, label='f1=%.3f auc=%.3f ap=%.3f' % (f1, pr_auc, ap))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.legend(loc="lower right")
plt.show()


# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# WARNING: Logging before flag parsing goes to stderr.
# W1010 10:59:15.241685 139991787947776 deprecation.py:506] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# (114855, 14, 14, 17)
# 234341 114855
# W1010 10:59:15.582916 139991787947776 deprecation.py:323] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 14, 14, 17, 3)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.4642 - acc: 0.3762 - mean_squared_error: 0.2511 - val_loss: 0.6973 - val_acc: 0.1417 - val_mean_squared_error: 0.2521
# Epoch 2/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.4480 - acc: 0.2546 - mean_squared_error: 0.2616 - val_loss: 0.7309 - val_acc: 0.2483 - val_mean_squared_error: 0.2688
# Epoch 3/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.4156 - acc: 0.3360 - mean_squared_error: 0.2731 - val_loss: 0.7886 - val_acc: 0.2331 - val_mean_squared_error: 0.2970
# Epoch 4/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.3823 - acc: 0.4115 - mean_squared_error: 0.2738 - val_loss: 0.7962 - val_acc: 0.3176 - val_mean_squared_error: 0.3002
# Epoch 5/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.3634 - acc: 0.4315 - mean_squared_error: 0.2745 - val_loss: 0.7998 - val_acc: 0.3441 - val_mean_squared_error: 0.3015
# Epoch 6/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.3469 - acc: 0.4354 - mean_squared_error: 0.2753 - val_loss: 0.7965 - val_acc: 0.3667 - val_mean_squared_error: 0.2996
# Epoch 7/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.3330 - acc: 0.4388 - mean_squared_error: 0.2750 - val_loss: 0.7855 - val_acc: 0.3871 - val_mean_squared_error: 0.2942
# Epoch 8/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.3230 - acc: 0.4394 - mean_squared_error: 0.2753 - val_loss: 0.7879 - val_acc: 0.3901 - val_mean_squared_error: 0.2952
# Epoch 9/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.3094 - acc: 0.4412 - mean_squared_error: 0.2748 - val_loss: 0.7795 - val_acc: 0.4017 - val_mean_squared_error: 0.2912
# Epoch 10/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.3013 - acc: 0.4423 - mean_squared_error: 0.2750 - val_loss: 0.7755 - val_acc: 0.4067 - val_mean_squared_error: 0.2893
# Epoch 11/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.2928 - acc: 0.4445 - mean_squared_error: 0.2744 - val_loss: 0.7701 - val_acc: 0.4142 - val_mean_squared_error: 0.2867
# Epoch 12/1000
# 585/585 [==============================] - 209s 357ms/step - loss: 1.2848 - acc: 0.4464 - mean_squared_error: 0.2734 - val_loss: 0.7609 - val_acc: 0.4225 - val_mean_squared_error: 0.2825
# Epoch 13/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.2727 - acc: 0.4475 - mean_squared_error: 0.2728 - val_loss: 0.7534 - val_acc: 0.4318 - val_mean_squared_error: 0.2790
# Epoch 14/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.2650 - acc: 0.4503 - mean_squared_error: 0.2720 - val_loss: 0.7499 - val_acc: 0.4356 - val_mean_squared_error: 0.2775
# Epoch 15/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.2583 - acc: 0.4538 - mean_squared_error: 0.2711 - val_loss: 0.7348 - val_acc: 0.4512 - val_mean_squared_error: 0.2706
# Epoch 16/1000
# 585/585 [==============================] - 210s 358ms/step - loss: 1.2555 - acc: 0.4576 - mean_squared_error: 0.2700 - val_loss: 0.7373 - val_acc: 0.4520 - val_mean_squared_error: 0.2718
# Epoch 17/1000
# 585/585 [==============================] - 209s 358ms/step - loss: 1.2485 - acc: 0.4605 - mean_squared_error: 0.2688 - val_loss: 0.7308 - val_acc: 0.4589 - val_mean_squared_error: 0.2688
# Epoch 18/1000
# 585/585 [==============================] - 210s 358ms/step - loss: 1.2391 - acc: 0.4657 - mean_squared_error: 0.2673 - val_loss: 0.7217 - val_acc: 0.4690 - val_mean_squared_error: 0.2648
# Epoch 19/1000
# 585/585 [==============================] - 210s 358ms/step - loss: 1.2323 - acc: 0.4703 - mean_squared_error: 0.2660 - val_loss: 0.7231 - val_acc: 0.4696 - val_mean_squared_error: 0.2655
# Epoch 20/1000
# 585/585 [==============================] - 210s 358ms/step - loss: 1.2252 - acc: 0.4741 - mean_squared_error: 0.2648 - val_loss: 0.7168 - val_acc: 0.4777 - val_mean_squared_error: 0.2627
# Epoch 21/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.2194 - acc: 0.4803 - mean_squared_error: 0.2629 - val_loss: 0.7193 - val_acc: 0.4787 - val_mean_squared_error: 0.2637
# Epoch 22/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.2121 - acc: 0.4861 - mean_squared_error: 0.2616 - val_loss: 0.7084 - val_acc: 0.4906 - val_mean_squared_error: 0.2589
# Epoch 23/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.2066 - acc: 0.4921 - mean_squared_error: 0.2603 - val_loss: 0.7089 - val_acc: 0.4930 - val_mean_squared_error: 0.2591
# Epoch 24/1000
# 585/585 [==============================] - 210s 358ms/step - loss: 1.1996 - acc: 0.4975 - mean_squared_error: 0.2587 - val_loss: 0.7082 - val_acc: 0.4946 - val_mean_squared_error: 0.2588
# Epoch 25/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1926 - acc: 0.5033 - mean_squared_error: 0.2572 - val_loss: 0.6931 - val_acc: 0.5110 - val_mean_squared_error: 0.2522
# Epoch 26/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1854 - acc: 0.5099 - mean_squared_error: 0.2554 - val_loss: 0.6901 - val_acc: 0.5171 - val_mean_squared_error: 0.2509
# Epoch 27/1000
# 585/585 [==============================] - 210s 360ms/step - loss: 1.1795 - acc: 0.5167 - mean_squared_error: 0.2537 - val_loss: 0.6746 - val_acc: 0.5350 - val_mean_squared_error: 0.2440
# Epoch 28/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1689 - acc: 0.5237 - mean_squared_error: 0.2520 - val_loss: 0.6664 - val_acc: 0.5454 - val_mean_squared_error: 0.2405
# Epoch 29/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1644 - acc: 0.5313 - mean_squared_error: 0.2500 - val_loss: 0.6603 - val_acc: 0.5555 - val_mean_squared_error: 0.2377
# Epoch 30/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1566 - acc: 0.5372 - mean_squared_error: 0.2484 - val_loss: 0.6514 - val_acc: 0.5662 - val_mean_squared_error: 0.2338
# Epoch 31/1000
# 585/585 [==============================] - 210s 360ms/step - loss: 1.1511 - acc: 0.5426 - mean_squared_error: 0.2470 - val_loss: 0.6454 - val_acc: 0.5749 - val_mean_squared_error: 0.2312
# Epoch 32/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.1426 - acc: 0.5508 - mean_squared_error: 0.2447 - val_loss: 0.6349 - val_acc: 0.5880 - val_mean_squared_error: 0.2266
# Epoch 33/1000
# 585/585 [==============================] - 210s 360ms/step - loss: 1.1365 - acc: 0.5580 - mean_squared_error: 0.2428 - val_loss: 0.6320 - val_acc: 0.5941 - val_mean_squared_error: 0.2252
# Epoch 34/1000
# 585/585 [==============================] - 210s 360ms/step - loss: 1.1307 - acc: 0.5630 - mean_squared_error: 0.2414 - val_loss: 0.6243 - val_acc: 0.6032 - val_mean_squared_error: 0.2219
# Epoch 35/1000
# 585/585 [==============================] - 210s 359ms/step - loss: 1.1208 - acc: 0.5699 - mean_squared_error: 0.2392 - val_loss: 0.6096 - val_acc: 0.6206 - val_mean_squared_error: 0.2154
# Epoch 36/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.1161 - acc: 0.5777 - mean_squared_error: 0.2372 - val_loss: 0.6112 - val_acc: 0.6202 - val_mean_squared_error: 0.2162
# Epoch 37/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.1097 - acc: 0.5839 - mean_squared_error: 0.2353 - val_loss: 0.5980 - val_acc: 0.6364 - val_mean_squared_error: 0.2104
# Epoch 38/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.1000 - acc: 0.5906 - mean_squared_error: 0.2336 - val_loss: 0.5876 - val_acc: 0.6497 - val_mean_squared_error: 0.2058
# Epoch 39/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0917 - acc: 0.5959 - mean_squared_error: 0.2316 - val_loss: 0.5815 - val_acc: 0.6583 - val_mean_squared_error: 0.2031
# Epoch 40/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.0883 - acc: 0.6027 - mean_squared_error: 0.2296 - val_loss: 0.5804 - val_acc: 0.6610 - val_mean_squared_error: 0.2026
# Epoch 41/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.0808 - acc: 0.6100 - mean_squared_error: 0.2272 - val_loss: 0.5733 - val_acc: 0.6691 - val_mean_squared_error: 0.1995
# Epoch 42/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.0733 - acc: 0.6143 - mean_squared_error: 0.2261 - val_loss: 0.5694 - val_acc: 0.6745 - val_mean_squared_error: 0.1977
# Epoch 43/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0671 - acc: 0.6210 - mean_squared_error: 0.2236 - val_loss: 0.5630 - val_acc: 0.6819 - val_mean_squared_error: 0.1948
# Epoch 44/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0617 - acc: 0.6254 - mean_squared_error: 0.2224 - val_loss: 0.5611 - val_acc: 0.6841 - val_mean_squared_error: 0.1940
# Epoch 45/1000
# 585/585 [==============================] - 211s 360ms/step - loss: 1.0538 - acc: 0.6317 - mean_squared_error: 0.2201 - val_loss: 0.5601 - val_acc: 0.6866 - val_mean_squared_error: 0.1935
# Epoch 46/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0466 - acc: 0.6377 - mean_squared_error: 0.2177 - val_loss: 0.5535 - val_acc: 0.6936 - val_mean_squared_error: 0.1906
# Epoch 47/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0420 - acc: 0.6429 - mean_squared_error: 0.2163 - val_loss: 0.5472 - val_acc: 0.7013 - val_mean_squared_error: 0.1878
# Epoch 48/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 1.0350 - acc: 0.6469 - mean_squared_error: 0.2146 - val_loss: 0.5431 - val_acc: 0.7061 - val_mean_squared_error: 0.1859
# Epoch 49/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 1.0295 - acc: 0.6508 - mean_squared_error: 0.2131 - val_loss: 0.5414 - val_acc: 0.7089 - val_mean_squared_error: 0.1851
# Epoch 50/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 1.0198 - acc: 0.6567 - mean_squared_error: 0.2109 - val_loss: 0.5362 - val_acc: 0.7149 - val_mean_squared_error: 0.1829
# Epoch 51/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 1.0157 - acc: 0.6609 - mean_squared_error: 0.2091 - val_loss: 0.5325 - val_acc: 0.7186 - val_mean_squared_error: 0.1813
# Epoch 52/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 1.0096 - acc: 0.6663 - mean_squared_error: 0.2073 - val_loss: 0.5286 - val_acc: 0.7227 - val_mean_squared_error: 0.1796
# Epoch 53/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 1.0019 - acc: 0.6696 - mean_squared_error: 0.2056 - val_loss: 0.5300 - val_acc: 0.7216 - val_mean_squared_error: 0.1802
# Epoch 54/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 0.9977 - acc: 0.6740 - mean_squared_error: 0.2039 - val_loss: 0.5217 - val_acc: 0.7292 - val_mean_squared_error: 0.1766
# Epoch 55/1000
# 585/585 [==============================] - 211s 361ms/step - loss: 0.9918 - acc: 0.6772 - mean_squared_error: 0.2026 - val_loss: 0.5234 - val_acc: 0.7275 - val_mean_squared_error: 0.1773
# Epoch 56/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9838 - acc: 0.6811 - mean_squared_error: 0.2006 - val_loss: 0.5117 - val_acc: 0.7379 - val_mean_squared_error: 0.1724
# Epoch 57/1000
# 585/585 [==============================] - 212s 362ms/step - loss: 0.9763 - acc: 0.6854 - mean_squared_error: 0.1989 - val_loss: 0.5104 - val_acc: 0.7394 - val_mean_squared_error: 0.1719
# Epoch 58/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9715 - acc: 0.6889 - mean_squared_error: 0.1972 - val_loss: 0.5021 - val_acc: 0.7467 - val_mean_squared_error: 0.1684
# Epoch 59/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9667 - acc: 0.6930 - mean_squared_error: 0.1957 - val_loss: 0.5039 - val_acc: 0.7453 - val_mean_squared_error: 0.1692
# Epoch 60/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9618 - acc: 0.6960 - mean_squared_error: 0.1944 - val_loss: 0.4967 - val_acc: 0.7513 - val_mean_squared_error: 0.1662
# Epoch 61/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9536 - acc: 0.7009 - mean_squared_error: 0.1926 - val_loss: 0.4899 - val_acc: 0.7563 - val_mean_squared_error: 0.1634
# Epoch 62/1000
# 585/585 [==============================] - 212s 363ms/step - loss: 0.9488 - acc: 0.7031 - mean_squared_error: 0.1911 - val_loss: 0.4812 - val_acc: 0.7632 - val_mean_squared_error: 0.1598
# Epoch 63/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9416 - acc: 0.7063 - mean_squared_error: 0.1898 - val_loss: 0.4794 - val_acc: 0.7646 - val_mean_squared_error: 0.1592
# Epoch 64/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9369 - acc: 0.7101 - mean_squared_error: 0.1882 - val_loss: 0.4679 - val_acc: 0.7738 - val_mean_squared_error: 0.1545
# Epoch 65/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9312 - acc: 0.7134 - mean_squared_error: 0.1864 - val_loss: 0.4701 - val_acc: 0.7718 - val_mean_squared_error: 0.1554
# Epoch 66/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9278 - acc: 0.7155 - mean_squared_error: 0.1855 - val_loss: 0.4751 - val_acc: 0.7673 - val_mean_squared_error: 0.1575
# Epoch 67/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9220 - acc: 0.7184 - mean_squared_error: 0.1841 - val_loss: 0.4687 - val_acc: 0.7716 - val_mean_squared_error: 0.1549
# Epoch 68/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9161 - acc: 0.7209 - mean_squared_error: 0.1826 - val_loss: 0.4696 - val_acc: 0.7709 - val_mean_squared_error: 0.1553
# Epoch 69/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9096 - acc: 0.7243 - mean_squared_error: 0.1811 - val_loss: 0.4586 - val_acc: 0.7795 - val_mean_squared_error: 0.1510
# Epoch 70/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9053 - acc: 0.7272 - mean_squared_error: 0.1798 - val_loss: 0.4621 - val_acc: 0.7766 - val_mean_squared_error: 0.1523
# Epoch 71/1000
# 585/585 [==============================] - 213s 364ms/step - loss: 0.9015 - acc: 0.7292 - mean_squared_error: 0.1787 - val_loss: 0.4521 - val_acc: 0.7839 - val_mean_squared_error: 0.1484
# Epoch 72/1000
# 585/585 [==============================] - 213s 365ms/step - loss: 0.8948 - acc: 0.7321 - mean_squared_error: 0.1772 - val_loss: 0.4539 - val_acc: 0.7825 - val_mean_squared_error: 0.1491
# Epoch 73/1000
# 585/585 [==============================] - 213s 365ms/step - loss: 0.8880 - acc: 0.7351 - mean_squared_error: 0.1761 - val_loss: 0.4492 - val_acc: 0.7860 - val_mean_squared_error: 0.1473
# Epoch 74/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8833 - acc: 0.7371 - mean_squared_error: 0.1745 - val_loss: 0.4443 - val_acc: 0.7891 - val_mean_squared_error: 0.1453
# Epoch 75/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8777 - acc: 0.7398 - mean_squared_error: 0.1733 - val_loss: 0.4445 - val_acc: 0.7891 - val_mean_squared_error: 0.1454
# Epoch 76/1000
# 585/585 [==============================] - 213s 365ms/step - loss: 0.8754 - acc: 0.7420 - mean_squared_error: 0.1722 - val_loss: 0.4478 - val_acc: 0.7863 - val_mean_squared_error: 0.1468
# Epoch 77/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8691 - acc: 0.7450 - mean_squared_error: 0.1709 - val_loss: 0.4471 - val_acc: 0.7862 - val_mean_squared_error: 0.1466
# Epoch 78/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8636 - acc: 0.7470 - mean_squared_error: 0.1695 - val_loss: 0.4565 - val_acc: 0.7793 - val_mean_squared_error: 0.1504
# Epoch 79/1000
# 585/585 [==============================] - 214s 365ms/step - loss: 0.8588 - acc: 0.7494 - mean_squared_error: 0.1683 - val_loss: 0.4617 - val_acc: 0.7755 - val_mean_squared_error: 0.1525
# Epoch 80/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8546 - acc: 0.7504 - mean_squared_error: 0.1674 - val_loss: 0.4622 - val_acc: 0.7753 - val_mean_squared_error: 0.1526
# Epoch 81/1000
# 585/585 [==============================] - 213s 365ms/step - loss: 0.8500 - acc: 0.7527 - mean_squared_error: 0.1664 - val_loss: 0.4770 - val_acc: 0.7644 - val_mean_squared_error: 0.1586
# Epoch 82/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8455 - acc: 0.7547 - mean_squared_error: 0.1652 - val_loss: 0.4737 - val_acc: 0.7667 - val_mean_squared_error: 0.1572
# Epoch 83/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8397 - acc: 0.7570 - mean_squared_error: 0.1638 - val_loss: 0.4739 - val_acc: 0.7665 - val_mean_squared_error: 0.1573
# Epoch 84/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8353 - acc: 0.7596 - mean_squared_error: 0.1627 - val_loss: 0.4731 - val_acc: 0.7675 - val_mean_squared_error: 0.1570
# Epoch 85/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8308 - acc: 0.7613 - mean_squared_error: 0.1616 - val_loss: 0.4647 - val_acc: 0.7732 - val_mean_squared_error: 0.1537
# Epoch 86/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8263 - acc: 0.7631 - mean_squared_error: 0.1606 - val_loss: 0.4603 - val_acc: 0.7760 - val_mean_squared_error: 0.1521
# Epoch 87/1000
# 585/585 [==============================] - 215s 367ms/step - loss: 0.8197 - acc: 0.7652 - mean_squared_error: 0.1595 - val_loss: 0.4520 - val_acc: 0.7818 - val_mean_squared_error: 0.1488
# Epoch 88/1000
# 585/585 [==============================] - 215s 367ms/step - loss: 0.8138 - acc: 0.7680 - mean_squared_error: 0.1581 - val_loss: 0.4447 - val_acc: 0.7870 - val_mean_squared_error: 0.1459
# Epoch 89/1000
# 585/585 [==============================] - 214s 366ms/step - loss: 0.8103 - acc: 0.7688 - mean_squared_error: 0.1574 - val_loss: 0.4423 - val_acc: 0.7886 - val_mean_squared_error: 0.1449
# Epoch 90/1000
# 585/585 [==============================] - 215s 367ms/step - loss: 0.8061 - acc: 0.7710 - mean_squared_error: 0.1562 - val_loss: 0.4366 - val_acc: 0.7924 - val_mean_squared_error: 0.1428
# Epoch 91/1000
#  43/585 [=>............................] - ETA: 3:31 - loss: 0.7065 - acc: 0.8140 - mean_squared_error: 0.1306
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 585/585 [==============================] - 215s 367ms/step - loss: 0.7608 - acc: 0.7891 - mean_squared_error: 0.1459 - val_loss: 0.4312 - val_acc: 0.7966 - val_mean_squared_error: 0.1406
# Epoch 101/1000
# 585/585 [==============================] - 215s 368ms/step - loss: 0.7583 - acc: 0.7895 - mean_squared_error: 0.1455 - val_loss: 0.4332 - val_acc: 0.7955 - val_mean_squared_error: 0.1413
# Epoch 102/1000
# 585/585 [==============================] - 215s 368ms/step - loss: 0.7509 - acc: 0.7920 - mean_squared_error: 0.1443 - val_loss: 0.4259 - val_acc: 0.8001 - val_mean_squared_error: 0.1385
# Epoch 103/1000
# 585/585 [==============================] - 216s 369ms/step - loss: 0.7493 - acc: 0.7932 - mean_squared_error: 0.1436 - val_loss: 0.4267 - val_acc: 0.7997 - val_mean_squared_error: 0.1388
# Epoch 104/1000
# 585/585 [==============================] - 216s 369ms/step - loss: 0.7436 - acc: 0.7947 - mean_squared_error: 0.1426 - val_loss: 0.4276 - val_acc: 0.7992 - val_mean_squared_error: 0.1391
# Epoch 105/1000
# 585/585 [==============================] - 216s 369ms/step - loss: 0.7387 - acc: 0.7961 - mean_squared_error: 0.1416 - val_loss: 0.4226 - val_acc: 0.8025 - val_mean_squared_error: 0.1372
# Epoch 106/1000
# 585/585 [==============================] - 216s 370ms/step - loss: 0.7361 - acc: 0.7976 - mean_squared_error: 0.1407 - val_loss: 0.4180 - val_acc: 0.8052 - val_mean_squared_error: 0.1355
# Epoch 107/1000
# 585/585 [==============================] - 216s 369ms/step - loss: 0.7325 - acc: 0.7985 - mean_squared_error: 0.1400 - val_loss: 0.4199 - val_acc: 0.8043 - val_mean_squared_error: 0.1362
# Epoch 108/1000
# 585/585 [==============================] - 216s 370ms/step - loss: 0.7272 - acc: 0.8002 - mean_squared_error: 0.1390 - val_loss: 0.4194 - val_acc: 0.8042 - val_mean_squared_error: 0.1361
# Epoch 109/1000
# 585/585 [==============================] - 216s 369ms/step - loss: 0.7196 - acc: 0.8022 - mean_squared_error: 0.1380 - val_loss: 0.4109 - val_acc: 0.8102 - val_mean_squared_error: 0.1329
# Epoch 110/1000
# 585/585 [==============================] - 216s 370ms/step - loss: 0.7168 - acc: 0.8037 - mean_squared_error: 0.1370 - val_loss: 0.4187 - val_acc: 0.8051 - val_mean_squared_error: 0.1358
# Epoch 111/1000
# 585/585 [==============================] - 216s 370ms/step - loss: 0.7145 - acc: 0.8048 - mean_squared_error: 0.1363 - val_loss: 0.4233 - val_acc: 0.8024 - val_mean_squared_error: 0.1375
# Epoch 112/1000
# 585/585 [==============================] - 217s 370ms/step - loss: 0.7094 - acc: 0.8072 - mean_squared_error: 0.1351 - val_loss: 0.4322 - val_acc: 0.7960 - val_mean_squared_error: 0.1410
# Epoch 113/1000
# 585/585 [==============================] - 216s 370ms/step - loss: 0.7068 - acc: 0.8080 - mean_squared_error: 0.1345 - val_loss: 0.4384 - val_acc: 0.7923 - val_mean_squared_error: 0.1433
# Epoch 114/1000
# 585/585 [==============================] - 217s 370ms/step - loss: 0.7005 - acc: 0.8098 - mean_squared_error: 0.1335 - val_loss: 0.4454 - val_acc: 0.7878 - val_mean_squared_error: 0.1460
# Epoch 115/1000
# 291/585 [=============>................] - ETA: 1:32 - loss: 0.7466 - acc: 0.7938 - mean_squared_error: 0.1434
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 585/585 [==============================] - 217s 371ms/step - loss: 0.6724 - acc: 0.8192 - mean_squared_error: 0.1278 - val_loss: 0.4761 - val_acc: 0.7702 - val_mean_squared_error: 0.1571
# Epoch 122/1000
# 585/585 [==============================] - 217s 371ms/step - loss: 0.6678 - acc: 0.8210 - mean_squared_error: 0.1268 - val_loss: 0.4671 - val_acc: 0.7751 - val_mean_squared_error: 0.1537
# Epoch 123/1000
# 585/585 [==============================] - 217s 371ms/step - loss: 0.6630 - acc: 0.8217 - mean_squared_error: 0.1260 - val_loss: 0.4636 - val_acc: 0.7774 - val_mean_squared_error: 0.1524
# Epoch 124/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6586 - acc: 0.8233 - mean_squared_error: 0.1251 - val_loss: 0.4672 - val_acc: 0.7755 - val_mean_squared_error: 0.1537
# Epoch 125/1000
# 585/585 [==============================] - 217s 372ms/step - loss: 0.6547 - acc: 0.8241 - mean_squared_error: 0.1245 - val_loss: 0.4590 - val_acc: 0.7805 - val_mean_squared_error: 0.1506
# Epoch 126/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6512 - acc: 0.8255 - mean_squared_error: 0.1237 - val_loss: 0.4641 - val_acc: 0.7777 - val_mean_squared_error: 0.1524
# Epoch 127/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6466 - acc: 0.8274 - mean_squared_error: 0.1227 - val_loss: 0.4538 - val_acc: 0.7842 - val_mean_squared_error: 0.1486
# Epoch 128/1000
# 585/585 [==============================] - 217s 371ms/step - loss: 0.6423 - acc: 0.8282 - mean_squared_error: 0.1219 - val_loss: 0.4587 - val_acc: 0.7816 - val_mean_squared_error: 0.1503
# Epoch 129/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6375 - acc: 0.8301 - mean_squared_error: 0.1211 - val_loss: 0.4526 - val_acc: 0.7857 - val_mean_squared_error: 0.1481
# Epoch 130/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6330 - acc: 0.8309 - mean_squared_error: 0.1202 - val_loss: 0.4395 - val_acc: 0.7936 - val_mean_squared_error: 0.1432
# Epoch 131/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6291 - acc: 0.8324 - mean_squared_error: 0.1193 - val_loss: 0.4407 - val_acc: 0.7932 - val_mean_squared_error: 0.1436
# Epoch 132/1000
# 585/585 [==============================] - 218s 372ms/step - loss: 0.6247 - acc: 0.8339 - mean_squared_error: 0.1185 - val_loss: 0.4421 - val_acc: 0.7928 - val_mean_squared_error: 0.1439
# Epoch 133/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.6195 - acc: 0.8355 - mean_squared_error: 0.1175 - val_loss: 0.4394 - val_acc: 0.7945 - val_mean_squared_error: 0.1428
# Epoch 134/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.6151 - acc: 0.8366 - mean_squared_error: 0.1168 - val_loss: 0.4374 - val_acc: 0.7962 - val_mean_squared_error: 0.1420
# Epoch 135/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.6122 - acc: 0.8381 - mean_squared_error: 0.1161 - val_loss: 0.4409 - val_acc: 0.7945 - val_mean_squared_error: 0.1432
# Epoch 136/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.6070 - acc: 0.8389 - mean_squared_error: 0.1152 - val_loss: 0.4381 - val_acc: 0.7957 - val_mean_squared_error: 0.1421
# Epoch 137/1000
# 585/585 [==============================] - 219s 374ms/step - loss: 0.6029 - acc: 0.8404 - mean_squared_error: 0.1144 - val_loss: 0.4417 - val_acc: 0.7942 - val_mean_squared_error: 0.1432
# Epoch 138/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.5992 - acc: 0.8416 - mean_squared_error: 0.1135 - val_loss: 0.4425 - val_acc: 0.7938 - val_mean_squared_error: 0.1434
# Epoch 139/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.5954 - acc: 0.8428 - mean_squared_error: 0.1128 - val_loss: 0.4394 - val_acc: 0.7959 - val_mean_squared_error: 0.1422
# Epoch 140/1000
# 585/585 [==============================] - 219s 374ms/step - loss: 0.5920 - acc: 0.8431 - mean_squared_error: 0.1123 - val_loss: 0.4332 - val_acc: 0.7997 - val_mean_squared_error: 0.1398
# Epoch 141/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.5881 - acc: 0.8449 - mean_squared_error: 0.1114 - val_loss: 0.4369 - val_acc: 0.7981 - val_mean_squared_error: 0.1411
# Epoch 142/1000
# 585/585 [==============================] - 218s 373ms/step - loss: 0.5821 - acc: 0.8463 - mean_squared_error: 0.1105 - val_loss: 0.4349 - val_acc: 0.7998 - val_mean_squared_error: 0.1402
# Epoch 143/1000
# 585/585 [==============================] - 219s 374ms/step - loss: 0.5795 - acc: 0.8470 - mean_squared_error: 0.1099 - val_loss: 0.4436 - val_acc: 0.7949 - val_mean_squared_error: 0.1432
# Epoch 144/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5754 - acc: 0.8482 - mean_squared_error: 0.1091 - val_loss: 0.4476 - val_acc: 0.7931 - val_mean_squared_error: 0.1445
# Epoch 145/1000
# 585/585 [==============================] - 219s 374ms/step - loss: 0.5708 - acc: 0.8496 - mean_squared_error: 0.1081 - val_loss: 0.4507 - val_acc: 0.7924 - val_mean_squared_error: 0.1453
# Epoch 146/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5665 - acc: 0.8510 - mean_squared_error: 0.1075 - val_loss: 0.4564 - val_acc: 0.7895 - val_mean_squared_error: 0.1473
# Epoch 147/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5626 - acc: 0.8522 - mean_squared_error: 0.1067 - val_loss: 0.4595 - val_acc: 0.7885 - val_mean_squared_error: 0.1482
# Epoch 148/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5574 - acc: 0.8531 - mean_squared_error: 0.1058 - val_loss: 0.4601 - val_acc: 0.7891 - val_mean_squared_error: 0.1482
# Epoch 149/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5538 - acc: 0.8543 - mean_squared_error: 0.1051 - val_loss: 0.4658 - val_acc: 0.7860 - val_mean_squared_error: 0.1501
# Epoch 150/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5503 - acc: 0.8553 - mean_squared_error: 0.1043 - val_loss: 0.4704 - val_acc: 0.7844 - val_mean_squared_error: 0.1515
# Epoch 151/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5455 - acc: 0.8564 - mean_squared_error: 0.1035 - val_loss: 0.4741 - val_acc: 0.7829 - val_mean_squared_error: 0.1526
# Epoch 152/1000
# 585/585 [==============================] - 219s 375ms/step - loss: 0.5413 - acc: 0.8583 - mean_squared_error: 0.1027 - val_loss: 0.4771 - val_acc: 0.7825 - val_mean_squared_error: 0.1533
# Epoch 153/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5367 - acc: 0.8590 - mean_squared_error: 0.1020 - val_loss: 0.4698 - val_acc: 0.7869 - val_mean_squared_error: 0.1506
# Epoch 154/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5338 - acc: 0.8601 - mean_squared_error: 0.1012 - val_loss: 0.4768 - val_acc: 0.7836 - val_mean_squared_error: 0.1528
# Epoch 155/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5289 - acc: 0.8614 - mean_squared_error: 0.1004 - val_loss: 0.4789 - val_acc: 0.7829 - val_mean_squared_error: 0.1533
# Epoch 156/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5254 - acc: 0.8620 - mean_squared_error: 0.0997 - val_loss: 0.4810 - val_acc: 0.7822 - val_mean_squared_error: 0.1539
# Epoch 157/1000
# 585/585 [==============================] - 220s 377ms/step - loss: 0.5212 - acc: 0.8632 - mean_squared_error: 0.0990 - val_loss: 0.4880 - val_acc: 0.7799 - val_mean_squared_error: 0.1559
# Epoch 158/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5182 - acc: 0.8645 - mean_squared_error: 0.0984 - val_loss: 0.5035 - val_acc: 0.7730 - val_mean_squared_error: 0.1609
# Epoch 159/1000
# 585/585 [==============================] - 220s 376ms/step - loss: 0.5127 - acc: 0.8657 - mean_squared_error: 0.0974 - val_loss: 0.5017 - val_acc: 0.7747 - val_mean_squared_error: 0.1600
# (114800, 1)
# (114800, 1)
# (114855,)
# CNN:
#
# [[78398 20277]
#  [ 5606 10519]] 0.77 0.81
#  BASELINE MODEL:
#
# [[98675     0]
#  [16125     0]] 0.86 0.5
#
#  RANDOM MODEL:
#
# [[49369 49306]
#  [ 8140  7985]] 0.5 0.5
