# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics

import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 100] = 0
                Y_batch_[Y_batch_ >= 100] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')
    
    na = 0
    pos = 0
    while (np.sum(rna[na]) > 100) and (na < len(rna)-1):
        pos +=1
        na +=1
    
    if pos == 0:
        continue

    if j <= num_test:
        if pos > len(rna)/2:
            X_test.extend(protein[:, :, :, :, :3])
            Y_test.extend(rna)
            num_aa_test +=len(rna)
        else:
            X_test.extend(protein[:pos, :, :, :, :3])
            X_test.extend(protein[-pos:, :, :, :, :3])
            Y_test.extend(rna[:pos])
            Y_test.extend(rna[-pos:])
            num_aa_test +=2*pos

    else:
        if pos > len(rna)/2:
            X_train.extend(protein[:, :, :, :, :3])
            Y_train.extend(rna)
            num_aa_train +=len(rna)
        else:
            X_train.extend(protein[:pos, :, :, :, :3])
            X_train.extend(protein[-pos:, :, :, :, :3])
            Y_train.extend(rna[:pos])
            Y_train.extend(rna[-pos:])
            num_aa_train +=2*pos


Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 100] = 0
Y_test_[Y_test_ >= 100] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400) 
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.6)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=500, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_new')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_new')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_ = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_.shape)


#CNN
Y_pred_prob = Y_pred_
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# (24252, 14, 14, 17)
# 46405 24252
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 14, 14, 17, 3)     0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/500
# 116/116 [==============================] - 31s 266ms/step - loss: 0.6961 - acc: 0.4895 - mean_squared_error: 0.2514 - val_loss: 0.6930 - val_acc: 0.5525 - val_mean_squared_error: 0.2499
# Epoch 2/500
# 116/116 [==============================] - 26s 228ms/step - loss: 0.6937 - acc: 0.4963 - mean_squared_error: 0.2503 - val_loss: 0.6928 - val_acc: 0.5605 - val_mean_squared_error: 0.2498
# Epoch 3/500
# 116/116 [==============================] - 26s 227ms/step - loss: 0.6925 - acc: 0.5121 - mean_squared_error: 0.2497 - val_loss: 0.6924 - val_acc: 0.5611 - val_mean_squared_error: 0.2496
# Epoch 4/500
# 116/116 [==============================] - 27s 230ms/step - loss: 0.6916 - acc: 0.5168 - mean_squared_error: 0.2492 - val_loss: 0.6916 - val_acc: 0.5615 - val_mean_squared_error: 0.2492
# Epoch 5/500
# 116/116 [==============================] - 27s 229ms/step - loss: 0.6906 - acc: 0.5251 - mean_squared_error: 0.2488 - val_loss: 0.6902 - val_acc: 0.5623 - val_mean_squared_error: 0.2485
# Epoch 6/500
# 116/116 [==============================] - 27s 231ms/step - loss: 0.6897 - acc: 0.5278 - mean_squared_error: 0.2483 - val_loss: 0.6874 - val_acc: 0.5716 - val_mean_squared_error: 0.2471
# Epoch 7/500
# 116/116 [==============================] - 27s 232ms/step - loss: 0.6878 - acc: 0.5400 - mean_squared_error: 0.2473 - val_loss: 0.6850 - val_acc: 0.5653 - val_mean_squared_error: 0.2459
# Epoch 8/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6869 - acc: 0.5448 - mean_squared_error: 0.2469 - val_loss: 0.6834 - val_acc: 0.5574 - val_mean_squared_error: 0.2452
# Epoch 9/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6853 - acc: 0.5485 - mean_squared_error: 0.2461 - val_loss: 0.6829 - val_acc: 0.5588 - val_mean_squared_error: 0.2449
# Epoch 10/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6834 - acc: 0.5500 - mean_squared_error: 0.2452 - val_loss: 0.6801 - val_acc: 0.5607 - val_mean_squared_error: 0.2436
# Epoch 11/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6810 - acc: 0.5574 - mean_squared_error: 0.2440 - val_loss: 0.6775 - val_acc: 0.5637 - val_mean_squared_error: 0.2423
# Epoch 12/500
# 116/116 [==============================] - 27s 232ms/step - loss: 0.6786 - acc: 0.5583 - mean_squared_error: 0.2429 - val_loss: 0.6758 - val_acc: 0.5646 - val_mean_squared_error: 0.2415
# Epoch 13/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6765 - acc: 0.5624 - mean_squared_error: 0.2418 - val_loss: 0.6739 - val_acc: 0.5679 - val_mean_squared_error: 0.2406
# Epoch 14/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6736 - acc: 0.5705 - mean_squared_error: 0.2405 - val_loss: 0.6715 - val_acc: 0.5713 - val_mean_squared_error: 0.2394
# Epoch 15/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.6706 - acc: 0.5742 - mean_squared_error: 0.2391 - val_loss: 0.6710 - val_acc: 0.5736 - val_mean_squared_error: 0.2392
# Epoch 16/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.6684 - acc: 0.5801 - mean_squared_error: 0.2380 - val_loss: 0.6677 - val_acc: 0.5803 - val_mean_squared_error: 0.2376
# Epoch 17/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6644 - acc: 0.5889 - mean_squared_error: 0.2361 - val_loss: 0.6673 - val_acc: 0.5750 - val_mean_squared_error: 0.2375
# Epoch 18/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6623 - acc: 0.5921 - mean_squared_error: 0.2351 - val_loss: 0.6657 - val_acc: 0.5764 - val_mean_squared_error: 0.2367
# Epoch 19/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6583 - acc: 0.5985 - mean_squared_error: 0.2332 - val_loss: 0.6658 - val_acc: 0.5766 - val_mean_squared_error: 0.2367
# Epoch 20/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6541 - acc: 0.6025 - mean_squared_error: 0.2313 - val_loss: 0.6595 - val_acc: 0.5842 - val_mean_squared_error: 0.2339
# Epoch 21/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6514 - acc: 0.6102 - mean_squared_error: 0.2300 - val_loss: 0.6591 - val_acc: 0.5849 - val_mean_squared_error: 0.2337
# Epoch 22/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.6483 - acc: 0.6111 - mean_squared_error: 0.2286 - val_loss: 0.6582 - val_acc: 0.5846 - val_mean_squared_error: 0.2333
# Epoch 23/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6434 - acc: 0.6197 - mean_squared_error: 0.2263 - val_loss: 0.6548 - val_acc: 0.5880 - val_mean_squared_error: 0.2316
# Epoch 24/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6389 - acc: 0.6243 - mean_squared_error: 0.2243 - val_loss: 0.6522 - val_acc: 0.5923 - val_mean_squared_error: 0.2304
# Epoch 25/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.6349 - acc: 0.6278 - mean_squared_error: 0.2224 - val_loss: 0.6499 - val_acc: 0.5984 - val_mean_squared_error: 0.2294
# Epoch 26/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6311 - acc: 0.6353 - mean_squared_error: 0.2207 - val_loss: 0.6475 - val_acc: 0.6031 - val_mean_squared_error: 0.2283
# Epoch 27/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6253 - acc: 0.6452 - mean_squared_error: 0.2180 - val_loss: 0.6446 - val_acc: 0.6235 - val_mean_squared_error: 0.2269
# Epoch 28/500
# 116/116 [==============================] - 28s 238ms/step - loss: 0.6221 - acc: 0.6433 - mean_squared_error: 0.2166 - val_loss: 0.6426 - val_acc: 0.6272 - val_mean_squared_error: 0.2260
# Epoch 29/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6178 - acc: 0.6522 - mean_squared_error: 0.2147 - val_loss: 0.6441 - val_acc: 0.6324 - val_mean_squared_error: 0.2267
# Epoch 30/500
# 116/116 [==============================] - 28s 237ms/step - loss: 0.6145 - acc: 0.6493 - mean_squared_error: 0.2132 - val_loss: 0.6415 - val_acc: 0.6414 - val_mean_squared_error: 0.2255
# Epoch 31/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.6090 - acc: 0.6603 - mean_squared_error: 0.2108 - val_loss: 0.6396 - val_acc: 0.6462 - val_mean_squared_error: 0.2246
# Epoch 32/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6049 - acc: 0.6647 - mean_squared_error: 0.2089 - val_loss: 0.6343 - val_acc: 0.6513 - val_mean_squared_error: 0.2224
# Epoch 33/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.6033 - acc: 0.6682 - mean_squared_error: 0.2083 - val_loss: 0.6395 - val_acc: 0.6492 - val_mean_squared_error: 0.2245
# Epoch 34/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5979 - acc: 0.6739 - mean_squared_error: 0.2059 - val_loss: 0.6345 - val_acc: 0.6568 - val_mean_squared_error: 0.2222
# Epoch 35/500
# 116/116 [==============================] - 28s 237ms/step - loss: 0.5946 - acc: 0.6761 - mean_squared_error: 0.2044 - val_loss: 0.6330 - val_acc: 0.6592 - val_mean_squared_error: 0.2215
# Epoch 36/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5909 - acc: 0.6791 - mean_squared_error: 0.2028 - val_loss: 0.6344 - val_acc: 0.6574 - val_mean_squared_error: 0.2221
# Epoch 37/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5867 - acc: 0.6827 - mean_squared_error: 0.2010 - val_loss: 0.6332 - val_acc: 0.6576 - val_mean_squared_error: 0.2217
# Epoch 38/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.5834 - acc: 0.6879 - mean_squared_error: 0.1995 - val_loss: 0.6340 - val_acc: 0.6562 - val_mean_squared_error: 0.2219
# Epoch 39/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5783 - acc: 0.6951 - mean_squared_error: 0.1974 - val_loss: 0.6332 - val_acc: 0.6563 - val_mean_squared_error: 0.2217
# Epoch 40/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5757 - acc: 0.6947 - mean_squared_error: 0.1962 - val_loss: 0.6299 - val_acc: 0.6611 - val_mean_squared_error: 0.2201
# Epoch 41/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.5710 - acc: 0.7007 - mean_squared_error: 0.1942 - val_loss: 0.6250 - val_acc: 0.6667 - val_mean_squared_error: 0.2179
# Epoch 42/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.5665 - acc: 0.7048 - mean_squared_error: 0.1923 - val_loss: 0.6251 - val_acc: 0.6648 - val_mean_squared_error: 0.2179
# Epoch 43/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.5643 - acc: 0.7071 - mean_squared_error: 0.1914 - val_loss: 0.6241 - val_acc: 0.6648 - val_mean_squared_error: 0.2175
# Epoch 44/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5610 - acc: 0.7094 - mean_squared_error: 0.1900 - val_loss: 0.6218 - val_acc: 0.6675 - val_mean_squared_error: 0.2165
# Epoch 45/500
# 116/116 [==============================] - 28s 237ms/step - loss: 0.5552 - acc: 0.7137 - mean_squared_error: 0.1875 - val_loss: 0.6201 - val_acc: 0.6708 - val_mean_squared_error: 0.2157
# Epoch 46/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5525 - acc: 0.7160 - mean_squared_error: 0.1865 - val_loss: 0.6183 - val_acc: 0.6721 - val_mean_squared_error: 0.2150
# Epoch 47/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5488 - acc: 0.7209 - mean_squared_error: 0.1848 - val_loss: 0.6155 - val_acc: 0.6769 - val_mean_squared_error: 0.2136
# Epoch 48/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5436 - acc: 0.7258 - mean_squared_error: 0.1827 - val_loss: 0.6165 - val_acc: 0.6730 - val_mean_squared_error: 0.2142
# Epoch 49/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5410 - acc: 0.7272 - mean_squared_error: 0.1816 - val_loss: 0.6209 - val_acc: 0.6677 - val_mean_squared_error: 0.2161
# Epoch 50/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5371 - acc: 0.7297 - mean_squared_error: 0.1800 - val_loss: 0.6140 - val_acc: 0.6748 - val_mean_squared_error: 0.2131
# Epoch 51/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5351 - acc: 0.7330 - mean_squared_error: 0.1791 - val_loss: 0.6148 - val_acc: 0.6762 - val_mean_squared_error: 0.2134
# Epoch 52/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5284 - acc: 0.7379 - mean_squared_error: 0.1764 - val_loss: 0.6150 - val_acc: 0.6726 - val_mean_squared_error: 0.2136
# Epoch 53/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5252 - acc: 0.7404 - mean_squared_error: 0.1751 - val_loss: 0.6117 - val_acc: 0.6776 - val_mean_squared_error: 0.2120
# Epoch 54/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.5232 - acc: 0.7413 - mean_squared_error: 0.1744 - val_loss: 0.6063 - val_acc: 0.6772 - val_mean_squared_error: 0.2101
# Epoch 55/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.5195 - acc: 0.7440 - mean_squared_error: 0.1729 - val_loss: 0.6115 - val_acc: 0.6747 - val_mean_squared_error: 0.2119
# Epoch 56/500
# 116/116 [==============================] - 28s 237ms/step - loss: 0.5158 - acc: 0.7453 - mean_squared_error: 0.1715 - val_loss: 0.6130 - val_acc: 0.6741 - val_mean_squared_error: 0.2123
# Epoch 57/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5110 - acc: 0.7514 - mean_squared_error: 0.1694 - val_loss: 0.6114 - val_acc: 0.6756 - val_mean_squared_error: 0.2116
# Epoch 58/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.5082 - acc: 0.7536 - mean_squared_error: 0.1683 - val_loss: 0.6068 - val_acc: 0.6841 - val_mean_squared_error: 0.2097
# Epoch 59/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.5041 - acc: 0.7563 - mean_squared_error: 0.1666 - val_loss: 0.6112 - val_acc: 0.6748 - val_mean_squared_error: 0.2115
# Epoch 60/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.5013 - acc: 0.7576 - mean_squared_error: 0.1656 - val_loss: 0.6096 - val_acc: 0.6767 - val_mean_squared_error: 0.2108
# Epoch 61/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4965 - acc: 0.7606 - mean_squared_error: 0.1637 - val_loss: 0.6084 - val_acc: 0.6757 - val_mean_squared_error: 0.2103
# Epoch 62/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.4914 - acc: 0.7674 - mean_squared_error: 0.1615 - val_loss: 0.6038 - val_acc: 0.6805 - val_mean_squared_error: 0.2084
# Epoch 63/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.4890 - acc: 0.7689 - mean_squared_error: 0.1607 - val_loss: 0.6099 - val_acc: 0.6771 - val_mean_squared_error: 0.2108
# Epoch 64/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.4873 - acc: 0.7679 - mean_squared_error: 0.1601 - val_loss: 0.6119 - val_acc: 0.6761 - val_mean_squared_error: 0.2115
# Epoch 65/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4807 - acc: 0.7761 - mean_squared_error: 0.1574 - val_loss: 0.6051 - val_acc: 0.6802 - val_mean_squared_error: 0.2085
# Epoch 66/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4795 - acc: 0.7728 - mean_squared_error: 0.1571 - val_loss: 0.6047 - val_acc: 0.6814 - val_mean_squared_error: 0.2081
# Epoch 67/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4757 - acc: 0.7771 - mean_squared_error: 0.1555 - val_loss: 0.6073 - val_acc: 0.6744 - val_mean_squared_error: 0.2093
# Epoch 68/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.4715 - acc: 0.7816 - mean_squared_error: 0.1539 - val_loss: 0.5984 - val_acc: 0.6829 - val_mean_squared_error: 0.2057
# Epoch 69/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4660 - acc: 0.7848 - mean_squared_error: 0.1518 - val_loss: 0.6081 - val_acc: 0.6770 - val_mean_squared_error: 0.2095
# Epoch 70/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4652 - acc: 0.7850 - mean_squared_error: 0.1515 - val_loss: 0.6105 - val_acc: 0.6750 - val_mean_squared_error: 0.2102
# Epoch 71/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4609 - acc: 0.7871 - mean_squared_error: 0.1500 - val_loss: 0.6076 - val_acc: 0.6759 - val_mean_squared_error: 0.2091
# Epoch 72/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4578 - acc: 0.7872 - mean_squared_error: 0.1488 - val_loss: 0.6071 - val_acc: 0.6763 - val_mean_squared_error: 0.2086
# Epoch 73/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4542 - acc: 0.7916 - mean_squared_error: 0.1473 - val_loss: 0.6100 - val_acc: 0.6742 - val_mean_squared_error: 0.2098
# Epoch 74/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4516 - acc: 0.7926 - mean_squared_error: 0.1465 - val_loss: 0.6077 - val_acc: 0.6738 - val_mean_squared_error: 0.2088
# Epoch 75/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4478 - acc: 0.7945 - mean_squared_error: 0.1450 - val_loss: 0.6041 - val_acc: 0.6778 - val_mean_squared_error: 0.2072
# Epoch 76/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4438 - acc: 0.7974 - mean_squared_error: 0.1435 - val_loss: 0.6053 - val_acc: 0.6762 - val_mean_squared_error: 0.2076
# Epoch 77/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4414 - acc: 0.8000 - mean_squared_error: 0.1426 - val_loss: 0.6081 - val_acc: 0.6750 - val_mean_squared_error: 0.2085
# Epoch 78/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.4346 - acc: 0.8043 - mean_squared_error: 0.1399 - val_loss: 0.6137 - val_acc: 0.6696 - val_mean_squared_error: 0.2107
# Epoch 79/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4357 - acc: 0.8019 - mean_squared_error: 0.1406 - val_loss: 0.6148 - val_acc: 0.6702 - val_mean_squared_error: 0.2109
# Epoch 80/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.4312 - acc: 0.8036 - mean_squared_error: 0.1388 - val_loss: 0.6163 - val_acc: 0.6697 - val_mean_squared_error: 0.2114
# Epoch 81/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.4268 - acc: 0.8081 - mean_squared_error: 0.1371 - val_loss: 0.6062 - val_acc: 0.6750 - val_mean_squared_error: 0.2079
# Epoch 82/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4251 - acc: 0.8074 - mean_squared_error: 0.1366 - val_loss: 0.6129 - val_acc: 0.6721 - val_mean_squared_error: 0.2099
# Epoch 83/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4219 - acc: 0.8103 - mean_squared_error: 0.1355 - val_loss: 0.6153 - val_acc: 0.6718 - val_mean_squared_error: 0.2107
# Epoch 84/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4178 - acc: 0.8132 - mean_squared_error: 0.1339 - val_loss: 0.6147 - val_acc: 0.6728 - val_mean_squared_error: 0.2103
# Epoch 85/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4156 - acc: 0.8127 - mean_squared_error: 0.1333 - val_loss: 0.6108 - val_acc: 0.6792 - val_mean_squared_error: 0.2085
# Epoch 86/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.4144 - acc: 0.8126 - mean_squared_error: 0.1328 - val_loss: 0.6126 - val_acc: 0.6758 - val_mean_squared_error: 0.2091
# Epoch 87/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4110 - acc: 0.8140 - mean_squared_error: 0.1316 - val_loss: 0.6125 - val_acc: 0.6792 - val_mean_squared_error: 0.2088
# Epoch 88/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.4080 - acc: 0.8164 - mean_squared_error: 0.1305 - val_loss: 0.6153 - val_acc: 0.6718 - val_mean_squared_error: 0.2099
# Epoch 89/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.4027 - acc: 0.8194 - mean_squared_error: 0.1286 - val_loss: 0.6122 - val_acc: 0.6769 - val_mean_squared_error: 0.2086
# Epoch 90/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3983 - acc: 0.8230 - mean_squared_error: 0.1268 - val_loss: 0.6202 - val_acc: 0.6695 - val_mean_squared_error: 0.2116
# Epoch 91/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.3956 - acc: 0.8239 - mean_squared_error: 0.1258 - val_loss: 0.6176 - val_acc: 0.6713 - val_mean_squared_error: 0.2105
# Epoch 92/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3954 - acc: 0.8239 - mean_squared_error: 0.1259 - val_loss: 0.6178 - val_acc: 0.6702 - val_mean_squared_error: 0.2104
# Epoch 93/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.3920 - acc: 0.8249 - mean_squared_error: 0.1247 - val_loss: 0.6069 - val_acc: 0.6793 - val_mean_squared_error: 0.2070
# Epoch 94/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.3902 - acc: 0.8265 - mean_squared_error: 0.1242 - val_loss: 0.6205 - val_acc: 0.6745 - val_mean_squared_error: 0.2110
# Epoch 95/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.3870 - acc: 0.8276 - mean_squared_error: 0.1231 - val_loss: 0.6145 - val_acc: 0.6806 - val_mean_squared_error: 0.2083
# Epoch 96/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3815 - acc: 0.8323 - mean_squared_error: 0.1210 - val_loss: 0.6164 - val_acc: 0.6804 - val_mean_squared_error: 0.2089
# Epoch 97/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3799 - acc: 0.8318 - mean_squared_error: 0.1204 - val_loss: 0.6204 - val_acc: 0.6781 - val_mean_squared_error: 0.2103
# Epoch 98/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3768 - acc: 0.8333 - mean_squared_error: 0.1193 - val_loss: 0.6238 - val_acc: 0.6748 - val_mean_squared_error: 0.2117
# Epoch 99/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3743 - acc: 0.8351 - mean_squared_error: 0.1185 - val_loss: 0.6249 - val_acc: 0.6752 - val_mean_squared_error: 0.2119
# Epoch 100/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3727 - acc: 0.8363 - mean_squared_error: 0.1181 - val_loss: 0.6276 - val_acc: 0.6731 - val_mean_squared_error: 0.2128
# Epoch 101/500
# 116/116 [==============================] - 27s 233ms/step - loss: 0.3703 - acc: 0.8368 - mean_squared_error: 0.1171 - val_loss: 0.6265 - val_acc: 0.6746 - val_mean_squared_error: 0.2120
# Epoch 102/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3686 - acc: 0.8372 - mean_squared_error: 0.1165 - val_loss: 0.6137 - val_acc: 0.6822 - val_mean_squared_error: 0.2075
# Epoch 103/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3664 - acc: 0.8376 - mean_squared_error: 0.1160 - val_loss: 0.6212 - val_acc: 0.6796 - val_mean_squared_error: 0.2098
# Epoch 104/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3641 - acc: 0.8393 - mean_squared_error: 0.1152 - val_loss: 0.6240 - val_acc: 0.6816 - val_mean_squared_error: 0.2100
# Epoch 105/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3586 - acc: 0.8431 - mean_squared_error: 0.1130 - val_loss: 0.6219 - val_acc: 0.6811 - val_mean_squared_error: 0.2093
# Epoch 106/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3580 - acc: 0.8428 - mean_squared_error: 0.1129 - val_loss: 0.6235 - val_acc: 0.6825 - val_mean_squared_error: 0.2095
# Epoch 107/500
# 116/116 [==============================] - 27s 234ms/step - loss: 0.3556 - acc: 0.8426 - mean_squared_error: 0.1121 - val_loss: 0.6228 - val_acc: 0.6817 - val_mean_squared_error: 0.2095
# Epoch 108/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3528 - acc: 0.8450 - mean_squared_error: 0.1111 - val_loss: 0.6209 - val_acc: 0.6864 - val_mean_squared_error: 0.2079
# Epoch 109/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3505 - acc: 0.8460 - mean_squared_error: 0.1103 - val_loss: 0.6289 - val_acc: 0.6817 - val_mean_squared_error: 0.2107
# Epoch 110/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3478 - acc: 0.8492 - mean_squared_error: 0.1094 - val_loss: 0.6384 - val_acc: 0.6764 - val_mean_squared_error: 0.2139
# Epoch 111/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3452 - acc: 0.8481 - mean_squared_error: 0.1085 - val_loss: 0.6311 - val_acc: 0.6846 - val_mean_squared_error: 0.2107
# Epoch 112/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3415 - acc: 0.8496 - mean_squared_error: 0.1073 - val_loss: 0.6342 - val_acc: 0.6833 - val_mean_squared_error: 0.2116
# Epoch 113/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3395 - acc: 0.8516 - mean_squared_error: 0.1065 - val_loss: 0.6348 - val_acc: 0.6815 - val_mean_squared_error: 0.2121
# Epoch 114/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3372 - acc: 0.8525 - mean_squared_error: 0.1058 - val_loss: 0.6332 - val_acc: 0.6880 - val_mean_squared_error: 0.2106
# Epoch 115/500
# 116/116 [==============================] - 27s 237ms/step - loss: 0.3366 - acc: 0.8522 - mean_squared_error: 0.1056 - val_loss: 0.6231 - val_acc: 0.6841 - val_mean_squared_error: 0.2088
# Epoch 116/500
# 116/116 [==============================] - 27s 236ms/step - loss: 0.3339 - acc: 0.8538 - mean_squared_error: 0.1046 - val_loss: 0.6359 - val_acc: 0.6817 - val_mean_squared_error: 0.2119
# Epoch 117/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3332 - acc: 0.8548 - mean_squared_error: 0.1045 - val_loss: 0.6441 - val_acc: 0.6792 - val_mean_squared_error: 0.2139
# Epoch 118/500
# 116/116 [==============================] - 27s 235ms/step - loss: 0.3277 - acc: 0.8592 - mean_squared_error: 0.1026 - val_loss: 0.6445 - val_acc: 0.6802 - val_mean_squared_error: 0.2138
# (24000, 1)
# (24000, 1)
# (24252,)
# CNN:
#
# [[8005 2905]
#  [4713 8377]] 0.68 0.69
#
#  BASELINE MODEL:
#
# [[10910     0]
#  [13090     0]] 0.45 0.5
#
#  RANDOM MODEL:
#
# [[5448 5462]
#  [6485 6605]] 0.5 0.5
