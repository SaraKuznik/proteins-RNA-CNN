# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics

import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 100] = 0
                Y_batch_[Y_batch_ >= 100] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
        

    else:
        X_train.extend(protein[:, :, :, :, :3])
        Y_train.extend(rna)
        num_aa_train +=len(rna)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 100] = 0
Y_test_[Y_test_ >= 100] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400) 
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.6)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=500, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_1_all')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_1_all')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_prob = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_prob.shape)

#CNN
Y_pred_ = np.copy(Y_pred_prob)
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y_test_, Y_pred_prob)
our_thr = np.where(np.round(thresholds, 2) == 0.5)[0]
roc_auc = sklearn.metrics.auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.plot(fpr[our_thr], tpr[our_thr])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.savefig('roc_curve')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==1)[0]], bins=100)
plt.savefig('positive_hist')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==0)[0]], bins=100)
plt.savefig('negative_hist')
plt.show()

precision, recall, _ = sklearn.metrics.precision_recall_curve(Y_test_, Y_pred_prob)
# calculate F1 score
f1 = sklearn.metrics.f1_score(Y_test_, Y_pred_)
# calculate precision-recall AUC
pr_auc = sklearn.metrics.auc(recall, precision)
# calculate average precision score
ap = sklearn.metrics.average_precision_score(Y_test_, Y_pred_prob)

plt.plot([0, 1], [0.1, 0.1], linestyle='--')
plt.plot(recall, precision, label='f1=%.3f auc=%.3f ap=%.3f' % (f1, pr_auc, ap))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.legend(loc="lower right")
plt.show()


# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# (147006, 14, 14, 17)
# 319356 147006
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 14, 14, 17, 3)     0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/500
# 798/798 [==============================] - 241s 302ms/step - loss: 0.5852 - acc: 0.8491 - mean_squared_error: 0.1977 - val_loss: 0.5984 - val_acc: 0.9105 - val_mean_squared_error: 0.2011
# Epoch 2/500
# 798/798 [==============================] - 254s 318ms/step - loss: 0.3884 - acc: 0.9214 - mean_squared_error: 0.1092 - val_loss: 0.4987 - val_acc: 0.9105 - val_mean_squared_error: 0.1528
# Epoch 3/500
# 798/798 [==============================] - 233s 292ms/step - loss: 0.3098 - acc: 0.9225 - mean_squared_error: 0.0813 - val_loss: 0.3988 - val_acc: 0.9104 - val_mean_squared_error: 0.1117
# Epoch 4/500
# 798/798 [==============================] - 234s 293ms/step - loss: 0.2653 - acc: 0.9227 - mean_squared_error: 0.0688 - val_loss: 0.3743 - val_acc: 0.9104 - val_mean_squared_error: 0.1024
# Epoch 5/500
# 798/798 [==============================] - 232s 291ms/step - loss: 0.2350 - acc: 0.9233 - mean_squared_error: 0.0616 - val_loss: 0.3477 - val_acc: 0.9101 - val_mean_squared_error: 0.0929
# Epoch 6/500
# 798/798 [==============================] - 245s 307ms/step - loss: 0.2147 - acc: 0.9230 - mean_squared_error: 0.0577 - val_loss: 0.3243 - val_acc: 0.9092 - val_mean_squared_error: 0.0853
# Epoch 7/500
# 798/798 [==============================] - 231s 290ms/step - loss: 0.1997 - acc: 0.9231 - mean_squared_error: 0.0552 - val_loss: 0.3031 - val_acc: 0.9088 - val_mean_squared_error: 0.0789
# Epoch 8/500
# 798/798 [==============================] - 245s 307ms/step - loss: 0.1882 - acc: 0.9238 - mean_squared_error: 0.0533 - val_loss: 0.2847 - val_acc: 0.9087 - val_mean_squared_error: 0.0739
# Epoch 9/500
# 798/798 [==============================] - 234s 293ms/step - loss: 0.1797 - acc: 0.9251 - mean_squared_error: 0.0518 - val_loss: 0.2695 - val_acc: 0.9083 - val_mean_squared_error: 0.0703
# Epoch 10/500
# 798/798 [==============================] - 236s 296ms/step - loss: 0.1744 - acc: 0.9250 - mean_squared_error: 0.0512 - val_loss: 0.2585 - val_acc: 0.9074 - val_mean_squared_error: 0.0682
# Epoch 11/500
# 798/798 [==============================] - 230s 289ms/step - loss: 0.1689 - acc: 0.9264 - mean_squared_error: 0.0501 - val_loss: 0.2461 - val_acc: 0.9074 - val_mean_squared_error: 0.0659
# Epoch 12/500
# 798/798 [==============================] - 237s 297ms/step - loss: 0.1635 - acc: 0.9283 - mean_squared_error: 0.0487 - val_loss: 0.2334 - val_acc: 0.9075 - val_mean_squared_error: 0.0639
# Epoch 13/500
# 798/798 [==============================] - 228s 285ms/step - loss: 0.1601 - acc: 0.9288 - mean_squared_error: 0.0481 - val_loss: 0.2218 - val_acc: 0.9082 - val_mean_squared_error: 0.0622
# Epoch 14/500
# 798/798 [==============================] - 239s 299ms/step - loss: 0.1563 - acc: 0.9302 - mean_squared_error: 0.0471 - val_loss: 0.2113 - val_acc: 0.9087 - val_mean_squared_error: 0.0610
# Epoch 15/500
# 798/798 [==============================] - 230s 289ms/step - loss: 0.1539 - acc: 0.9314 - mean_squared_error: 0.0463 - val_loss: 0.2063 - val_acc: 0.9087 - val_mean_squared_error: 0.0608
# Epoch 16/500
# 798/798 [==============================] - 244s 305ms/step - loss: 0.1506 - acc: 0.9335 - mean_squared_error: 0.0453 - val_loss: 0.2033 - val_acc: 0.9089 - val_mean_squared_error: 0.0606
# Epoch 17/500
# 798/798 [==============================] - 226s 283ms/step - loss: 0.1484 - acc: 0.9349 - mean_squared_error: 0.0446 - val_loss: 0.2023 - val_acc: 0.9099 - val_mean_squared_error: 0.0606
# Epoch 18/500
# 798/798 [==============================] - 252s 315ms/step - loss: 0.1476 - acc: 0.9357 - mean_squared_error: 0.0444 - val_loss: 0.2020 - val_acc: 0.9095 - val_mean_squared_error: 0.0609
# Epoch 19/500
# 798/798 [==============================] - 224s 280ms/step - loss: 0.1461 - acc: 0.9368 - mean_squared_error: 0.0439 - val_loss: 0.2018 - val_acc: 0.9098 - val_mean_squared_error: 0.0610
# Epoch 20/500
# 798/798 [==============================] - 248s 310ms/step - loss: 0.1442 - acc: 0.9378 - mean_squared_error: 0.0432 - val_loss: 0.1972 - val_acc: 0.9113 - val_mean_squared_error: 0.0599
# Epoch 21/500
# 798/798 [==============================] - 225s 282ms/step - loss: 0.1428 - acc: 0.9387 - mean_squared_error: 0.0427 - val_loss: 0.1963 - val_acc: 0.9115 - val_mean_squared_error: 0.0598
# Epoch 22/500
# 798/798 [==============================] - 244s 306ms/step - loss: 0.1410 - acc: 0.9398 - mean_squared_error: 0.0421 - val_loss: 0.1975 - val_acc: 0.9098 - val_mean_squared_error: 0.0604
# Epoch 23/500
# 798/798 [==============================] - 223s 279ms/step - loss: 0.1397 - acc: 0.9406 - mean_squared_error: 0.0416 - val_loss: 0.1959 - val_acc: 0.9101 - val_mean_squared_error: 0.0600
# Epoch 24/500
# 798/798 [==============================] - 248s 311ms/step - loss: 0.1380 - acc: 0.9419 - mean_squared_error: 0.0410 - val_loss: 0.1936 - val_acc: 0.9106 - val_mean_squared_error: 0.0595
# Epoch 25/500
# 798/798 [==============================] - 222s 278ms/step - loss: 0.1361 - acc: 0.9429 - mean_squared_error: 0.0403 - val_loss: 0.1927 - val_acc: 0.9101 - val_mean_squared_error: 0.0595
# Epoch 26/500
# 798/798 [==============================] - 255s 320ms/step - loss: 0.1349 - acc: 0.9439 - mean_squared_error: 0.0398 - val_loss: 0.1917 - val_acc: 0.9097 - val_mean_squared_error: 0.0595
# Epoch 27/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1331 - acc: 0.9448 - mean_squared_error: 0.0392 - val_loss: 0.1898 - val_acc: 0.9100 - val_mean_squared_error: 0.0591
# Epoch 28/500
# 798/798 [==============================] - 256s 320ms/step - loss: 0.1311 - acc: 0.9460 - mean_squared_error: 0.0385 - val_loss: 0.1877 - val_acc: 0.9107 - val_mean_squared_error: 0.0586
# Epoch 29/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1276 - acc: 0.9475 - mean_squared_error: 0.0376 - val_loss: 0.1861 - val_acc: 0.9111 - val_mean_squared_error: 0.0583
# Epoch 30/500
# 798/798 [==============================] - 245s 307ms/step - loss: 0.1277 - acc: 0.9481 - mean_squared_error: 0.0374 - val_loss: 0.1833 - val_acc: 0.9121 - val_mean_squared_error: 0.0575
# Epoch 31/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.1258 - acc: 0.9493 - mean_squared_error: 0.0367 - val_loss: 0.1820 - val_acc: 0.9126 - val_mean_squared_error: 0.0572
# Epoch 32/500
# 798/798 [==============================] - 254s 318ms/step - loss: 0.1239 - acc: 0.9503 - mean_squared_error: 0.0361 - val_loss: 0.1823 - val_acc: 0.9123 - val_mean_squared_error: 0.0573
# Epoch 33/500
# 798/798 [==============================] - 218s 274ms/step - loss: 0.1219 - acc: 0.9516 - mean_squared_error: 0.0353 - val_loss: 0.1812 - val_acc: 0.9126 - val_mean_squared_error: 0.0571
# Epoch 34/500
# 798/798 [==============================] - 257s 322ms/step - loss: 0.1200 - acc: 0.9528 - mean_squared_error: 0.0347 - val_loss: 0.1803 - val_acc: 0.9128 - val_mean_squared_error: 0.0568
# Epoch 35/500
# 798/798 [==============================] - 216s 271ms/step - loss: 0.1184 - acc: 0.9535 - mean_squared_error: 0.0342 - val_loss: 0.1795 - val_acc: 0.9132 - val_mean_squared_error: 0.0566
# Epoch 36/500
# 798/798 [==============================] - 258s 323ms/step - loss: 0.1169 - acc: 0.9546 - mean_squared_error: 0.0337 - val_loss: 0.1790 - val_acc: 0.9134 - val_mean_squared_error: 0.0565
# Epoch 37/500
# 798/798 [==============================] - 216s 270ms/step - loss: 0.1150 - acc: 0.9556 - mean_squared_error: 0.0330 - val_loss: 0.1787 - val_acc: 0.9137 - val_mean_squared_error: 0.0564
# Epoch 38/500
# 798/798 [==============================] - 258s 323ms/step - loss: 0.1134 - acc: 0.9567 - mean_squared_error: 0.0324 - val_loss: 0.1782 - val_acc: 0.9141 - val_mean_squared_error: 0.0563
# Epoch 39/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.1115 - acc: 0.9579 - mean_squared_error: 0.0317 - val_loss: 0.1784 - val_acc: 0.9143 - val_mean_squared_error: 0.0563
# Epoch 40/500
# 798/798 [==============================] - 268s 336ms/step - loss: 0.1093 - acc: 0.9591 - mean_squared_error: 0.0310 - val_loss: 0.1768 - val_acc: 0.9154 - val_mean_squared_error: 0.0558
# Epoch 41/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.1076 - acc: 0.9603 - mean_squared_error: 0.0303 - val_loss: 0.1765 - val_acc: 0.9161 - val_mean_squared_error: 0.0557
# Epoch 42/500
# 798/798 [==============================] - 271s 340ms/step - loss: 0.1062 - acc: 0.9613 - mean_squared_error: 0.0299 - val_loss: 0.1774 - val_acc: 0.9161 - val_mean_squared_error: 0.0559
# Epoch 43/500
# 798/798 [==============================] - 213s 267ms/step - loss: 0.1052 - acc: 0.9616 - mean_squared_error: 0.0295 - val_loss: 0.1778 - val_acc: 0.9162 - val_mean_squared_error: 0.0560
# Epoch 44/500
# 798/798 [==============================] - 270s 338ms/step - loss: 0.1039 - acc: 0.9625 - mean_squared_error: 0.0290 - val_loss: 0.1770 - val_acc: 0.9164 - val_mean_squared_error: 0.0557
# Epoch 45/500
# 798/798 [==============================] - 210s 264ms/step - loss: 0.1021 - acc: 0.9636 - mean_squared_error: 0.0284 - val_loss: 0.1778 - val_acc: 0.9164 - val_mean_squared_error: 0.0559
# Epoch 46/500
# 798/798 [==============================] - 269s 338ms/step - loss: 0.1006 - acc: 0.9643 - mean_squared_error: 0.0278 - val_loss: 0.1789 - val_acc: 0.9160 - val_mean_squared_error: 0.0563
# Epoch 47/500
# 798/798 [==============================] - 213s 267ms/step - loss: 0.0987 - acc: 0.9654 - mean_squared_error: 0.0272 - val_loss: 0.1795 - val_acc: 0.9157 - val_mean_squared_error: 0.0565
# Epoch 48/500
# 798/798 [==============================] - 262s 329ms/step - loss: 0.0972 - acc: 0.9663 - mean_squared_error: 0.0267 - val_loss: 0.1808 - val_acc: 0.9157 - val_mean_squared_error: 0.0568
# Epoch 49/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.0960 - acc: 0.9669 - mean_squared_error: 0.0263 - val_loss: 0.1820 - val_acc: 0.9157 - val_mean_squared_error: 0.0570
# Epoch 50/500
# 798/798 [==============================] - 275s 344ms/step - loss: 0.0942 - acc: 0.9680 - mean_squared_error: 0.0256 - val_loss: 0.1855 - val_acc: 0.9142 - val_mean_squared_error: 0.0582
# Epoch 51/500
# 798/798 [==============================] - 210s 263ms/step - loss: 0.0925 - acc: 0.9687 - mean_squared_error: 0.0251 - val_loss: 0.1856 - val_acc: 0.9149 - val_mean_squared_error: 0.0580
# Epoch 52/500
# 798/798 [==============================] - 277s 348ms/step - loss: 0.0920 - acc: 0.9692 - mean_squared_error: 0.0249 - val_loss: 0.1865 - val_acc: 0.9149 - val_mean_squared_error: 0.0582
# Epoch 53/500
# 798/798 [==============================] - 210s 263ms/step - loss: 0.0903 - acc: 0.9698 - mean_squared_error: 0.0243 - val_loss: 0.1875 - val_acc: 0.9148 - val_mean_squared_error: 0.0584
# Epoch 54/500
# 798/798 [==============================] - 277s 347ms/step - loss: 0.0892 - acc: 0.9705 - mean_squared_error: 0.0240 - val_loss: 0.1880 - val_acc: 0.9151 - val_mean_squared_error: 0.0585
# Epoch 55/500
# 798/798 [==============================] - 211s 264ms/step - loss: 0.0879 - acc: 0.9711 - mean_squared_error: 0.0235 - val_loss: 0.1890 - val_acc: 0.9151 - val_mean_squared_error: 0.0586
# Epoch 56/500
# 798/798 [==============================] - 268s 336ms/step - loss: 0.0865 - acc: 0.9717 - mean_squared_error: 0.0231 - val_loss: 0.1897 - val_acc: 0.9149 - val_mean_squared_error: 0.0589
# Epoch 57/500
# 798/798 [==============================] - 210s 263ms/step - loss: 0.0853 - acc: 0.9721 - mean_squared_error: 0.0227 - val_loss: 0.1907 - val_acc: 0.9150 - val_mean_squared_error: 0.0591
# Epoch 58/500
# 798/798 [==============================] - 268s 336ms/step - loss: 0.0839 - acc: 0.9731 - mean_squared_error: 0.0222 - val_loss: 0.1900 - val_acc: 0.9160 - val_mean_squared_error: 0.0586
# Epoch 59/500
# 798/798 [==============================] - 211s 264ms/step - loss: 0.0829 - acc: 0.9734 - mean_squared_error: 0.0219 - val_loss: 0.1904 - val_acc: 0.9156 - val_mean_squared_error: 0.0588
# Epoch 60/500
# 798/798 [==============================] - 272s 341ms/step - loss: 0.0818 - acc: 0.9739 - mean_squared_error: 0.0215 - val_loss: 0.1927 - val_acc: 0.9150 - val_mean_squared_error: 0.0595
# Epoch 61/500
# 798/798 [==============================] - 210s 264ms/step - loss: 0.0809 - acc: 0.9743 - mean_squared_error: 0.0212 - val_loss: 0.1909 - val_acc: 0.9171 - val_mean_squared_error: 0.0584
# Epoch 62/500
# 798/798 [==============================] - 276s 346ms/step - loss: 0.0793 - acc: 0.9748 - mean_squared_error: 0.0208 - val_loss: 0.1921 - val_acc: 0.9164 - val_mean_squared_error: 0.0588
# Epoch 63/500
# 798/798 [==============================] - 213s 267ms/step - loss: 0.0779 - acc: 0.9754 - mean_squared_error: 0.0204 - val_loss: 0.1927 - val_acc: 0.9169 - val_mean_squared_error: 0.0586
# Epoch 64/500
# 798/798 [==============================] - 268s 336ms/step - loss: 0.0774 - acc: 0.9758 - mean_squared_error: 0.0201 - val_loss: 0.1943 - val_acc: 0.9159 - val_mean_squared_error: 0.0593
# Epoch 65/500
# 798/798 [==============================] - 211s 264ms/step - loss: 0.0761 - acc: 0.9761 - mean_squared_error: 0.0197 - val_loss: 0.1964 - val_acc: 0.9151 - val_mean_squared_error: 0.0599
# Epoch 66/500
# 798/798 [==============================] - 269s 337ms/step - loss: 0.0749 - acc: 0.9766 - mean_squared_error: 0.0194 - val_loss: 0.1963 - val_acc: 0.9155 - val_mean_squared_error: 0.0597
# Epoch 67/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.0740 - acc: 0.9768 - mean_squared_error: 0.0191 - val_loss: 0.1983 - val_acc: 0.9153 - val_mean_squared_error: 0.0602
# Epoch 68/500
# 798/798 [==============================] - 273s 342ms/step - loss: 0.0730 - acc: 0.9772 - mean_squared_error: 0.0188 - val_loss: 0.2010 - val_acc: 0.9150 - val_mean_squared_error: 0.0607
# Epoch 69/500
# 798/798 [==============================] - 214s 269ms/step - loss: 0.0718 - acc: 0.9778 - mean_squared_error: 0.0185 - val_loss: 0.1998 - val_acc: 0.9160 - val_mean_squared_error: 0.0601
# Epoch 70/500
# 798/798 [==============================] - 276s 346ms/step - loss: 0.0708 - acc: 0.9782 - mean_squared_error: 0.0181 - val_loss: 0.2001 - val_acc: 0.9156 - val_mean_squared_error: 0.0603
# Epoch 71/500
# 798/798 [==============================] - 210s 264ms/step - loss: 0.0694 - acc: 0.9785 - mean_squared_error: 0.0178 - val_loss: 0.2015 - val_acc: 0.9154 - val_mean_squared_error: 0.0606
# Epoch 72/500
# 798/798 [==============================] - 273s 342ms/step - loss: 0.0689 - acc: 0.9789 - mean_squared_error: 0.0176 - val_loss: 0.2028 - val_acc: 0.9157 - val_mean_squared_error: 0.0606
# Epoch 73/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.0676 - acc: 0.9792 - mean_squared_error: 0.0172 - val_loss: 0.2036 - val_acc: 0.9157 - val_mean_squared_error: 0.0607
# Epoch 74/500
# 798/798 [==============================] - 277s 347ms/step - loss: 0.0667 - acc: 0.9796 - mean_squared_error: 0.0170 - val_loss: 0.2030 - val_acc: 0.9161 - val_mean_squared_error: 0.0606
# Epoch 75/500
# 798/798 [==============================] - 214s 269ms/step - loss: 0.0657 - acc: 0.9799 - mean_squared_error: 0.0167 - val_loss: 0.2041 - val_acc: 0.9164 - val_mean_squared_error: 0.0606
# Epoch 76/500
# 798/798 [==============================] - 281s 352ms/step - loss: 0.0648 - acc: 0.9803 - mean_squared_error: 0.0164 - val_loss: 0.2051 - val_acc: 0.9164 - val_mean_squared_error: 0.0606
# Epoch 77/500
# 798/798 [==============================] - 215s 269ms/step - loss: 0.0638 - acc: 0.9807 - mean_squared_error: 0.0162 - val_loss: 0.2079 - val_acc: 0.9151 - val_mean_squared_error: 0.0616
# Epoch 78/500
# 798/798 [==============================] - 274s 344ms/step - loss: 0.0631 - acc: 0.9808 - mean_squared_error: 0.0160 - val_loss: 0.2081 - val_acc: 0.9150 - val_mean_squared_error: 0.0617
# Epoch 79/500
# 798/798 [==============================] - 212s 266ms/step - loss: 0.0624 - acc: 0.9810 - mean_squared_error: 0.0158 - val_loss: 0.2081 - val_acc: 0.9152 - val_mean_squared_error: 0.0616
# Epoch 80/500
# 798/798 [==============================] - 266s 333ms/step - loss: 0.0618 - acc: 0.9812 - mean_squared_error: 0.0157 - val_loss: 0.2096 - val_acc: 0.9156 - val_mean_squared_error: 0.0615
# Epoch 81/500
# 798/798 [==============================] - 210s 264ms/step - loss: 0.0606 - acc: 0.9816 - mean_squared_error: 0.0153 - val_loss: 0.2071 - val_acc: 0.9160 - val_mean_squared_error: 0.0611
# Epoch 82/500
# 798/798 [==============================] - 267s 335ms/step - loss: 0.0601 - acc: 0.9818 - mean_squared_error: 0.0152 - val_loss: 0.2075 - val_acc: 0.9161 - val_mean_squared_error: 0.0611
# Epoch 83/500
# 798/798 [==============================] - 216s 270ms/step - loss: 0.0593 - acc: 0.9820 - mean_squared_error: 0.0150 - val_loss: 0.2087 - val_acc: 0.9170 - val_mean_squared_error: 0.0609
# Epoch 84/500
# 798/798 [==============================] - 266s 333ms/step - loss: 0.0585 - acc: 0.9823 - mean_squared_error: 0.0148 - val_loss: 0.2101 - val_acc: 0.9169 - val_mean_squared_error: 0.0610
# Epoch 85/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.0575 - acc: 0.9825 - mean_squared_error: 0.0145 - val_loss: 0.2133 - val_acc: 0.9159 - val_mean_squared_error: 0.0618
# Epoch 86/500
# 798/798 [==============================] - 262s 329ms/step - loss: 0.0568 - acc: 0.9828 - mean_squared_error: 0.0143 - val_loss: 0.2135 - val_acc: 0.9158 - val_mean_squared_error: 0.0619
# Epoch 87/500
# 798/798 [==============================] - 211s 265ms/step - loss: 0.0560 - acc: 0.9831 - mean_squared_error: 0.0141 - val_loss: 0.2145 - val_acc: 0.9160 - val_mean_squared_error: 0.0620
# Epoch 88/500
# 798/798 [==============================] - 270s 338ms/step - loss: 0.0551 - acc: 0.9834 - mean_squared_error: 0.0138 - val_loss: 0.2159 - val_acc: 0.9160 - val_mean_squared_error: 0.0621
# Epoch 89/500
# 798/798 [==============================] - 215s 269ms/step - loss: 0.0543 - acc: 0.9834 - mean_squared_error: 0.0137 - val_loss: 0.2169 - val_acc: 0.9161 - val_mean_squared_error: 0.0621
# Epoch 90/500
# 798/798 [==============================] - 269s 337ms/step - loss: 0.0538 - acc: 0.9838 - mean_squared_error: 0.0135 - val_loss: 0.2172 - val_acc: 0.9166 - val_mean_squared_error: 0.0619
# Epoch 91/500
# 798/798 [==============================] - 214s 268ms/step - loss: 0.0529 - acc: 0.9840 - mean_squared_error: 0.0133 - val_loss: 0.2186 - val_acc: 0.9166 - val_mean_squared_error: 0.0621
# (146800, 1)
# (146800, 1)
# (147006,)
# CNN:
#
# [[128415   5242]
#  [  6987   6156]] 0.92 0.92
#  BASELINE MODEL:
#
# [[133657      0]
#  [ 13143      0]] 0.91 0.5
#
#  RANDOM MODEL:
#
# [[66982 66675]
#  [ 6497  6646]] 0.5 0.5
