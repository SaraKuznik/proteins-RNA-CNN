# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics

import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 100] = 0
                Y_batch_[Y_batch_ >= 100] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
        

    else:
        X_train.extend(protein[:, :, :, :, :3])
        Y_train.extend(rna)
        num_aa_train +=len(rna)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 100] = 0
Y_test_[Y_test_ >= 100] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/400) 
n_steps_test = int(num_aa_test/400)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 400, True)
generator_validation = generator(X_test, Y_test, 400, True)
generator_test = generator(X_test, Y_test, 400, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.6)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=500, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_1_all')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_1_all')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_prob = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_prob.shape)

#CNN
Y_pred_ = np.copy(Y_pred_prob)
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

fpr, tpr, thresholds = sklearn.metrics.roc_curve(Y_test_, Y_pred_prob)
print(len(thresholds))
roc_auc = sklearn.metrics.auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.savefig('roc_curve')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==1)[0]], bins=100)
plt.savefig('positive_hist')
plt.show()

plt.hist(Y_pred_prob[np.where(Y_test_==0)[0]], bins=100)
plt.savefig('negative_hist')
plt.show()


# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# (147006, 14, 14, 17)
# 319356 147006
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 14, 14, 17, 3)     0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/500
# 798/798 [==============================] - 243s 305ms/step - loss: 0.5666 - acc: 0.8443 - mean_squared_error: 0.1889 - val_loss: 0.5643 - val_acc: 0.9104 - val_mean_squared_error: 0.1860
# Epoch 2/500
# 798/798 [==============================] - 244s 305ms/step - loss: 0.3804 - acc: 0.9221 - mean_squared_error: 0.1063 - val_loss: 0.4891 - val_acc: 0.9105 - val_mean_squared_error: 0.1494
# Epoch 3/500
# 798/798 [==============================] - 243s 304ms/step - loss: 0.3087 - acc: 0.9227 - mean_squared_error: 0.0811 - val_loss: 0.3838 - val_acc: 0.9105 - val_mean_squared_error: 0.1060
# Epoch 4/500
# 798/798 [==============================] - 238s 298ms/step - loss: 0.2651 - acc: 0.9217 - mean_squared_error: 0.0693 - val_loss: 0.2868 - val_acc: 0.9105 - val_mean_squared_error: 0.0751
# Epoch 5/500
# 798/798 [==============================] - 238s 298ms/step - loss: 0.2290 - acc: 0.9209 - mean_squared_error: 0.0608 - val_loss: 0.2501 - val_acc: 0.9105 - val_mean_squared_error: 0.0665
# Epoch 6/500
# 798/798 [==============================] - 235s 295ms/step - loss: 0.2079 - acc: 0.9205 - mean_squared_error: 0.0569 - val_loss: 0.2270 - val_acc: 0.9105 - val_mean_squared_error: 0.0623
# Epoch 7/500
# 798/798 [==============================] - 240s 301ms/step - loss: 0.1936 - acc: 0.9204 - mean_squared_error: 0.0547 - val_loss: 0.2124 - val_acc: 0.9106 - val_mean_squared_error: 0.0604
# Epoch 8/500
# 798/798 [==============================] - 239s 300ms/step - loss: 0.1833 - acc: 0.9213 - mean_squared_error: 0.0531 - val_loss: 0.2031 - val_acc: 0.9107 - val_mean_squared_error: 0.0597
# Epoch 9/500
# 798/798 [==============================] - 237s 298ms/step - loss: 0.1753 - acc: 0.9220 - mean_squared_error: 0.0516 - val_loss: 0.1964 - val_acc: 0.9107 - val_mean_squared_error: 0.0593
# Epoch 10/500
# 798/798 [==============================] - 238s 299ms/step - loss: 0.1711 - acc: 0.9212 - mean_squared_error: 0.0512 - val_loss: 0.1927 - val_acc: 0.9108 - val_mean_squared_error: 0.0588
# Epoch 11/500
# 798/798 [==============================] - 235s 294ms/step - loss: 0.1664 - acc: 0.9218 - mean_squared_error: 0.0503 - val_loss: 0.1901 - val_acc: 0.9111 - val_mean_squared_error: 0.0587
# Epoch 12/500
# 798/798 [==============================] - 240s 301ms/step - loss: 0.1621 - acc: 0.9226 - mean_squared_error: 0.0494 - val_loss: 0.1895 - val_acc: 0.9111 - val_mean_squared_error: 0.0587
# Epoch 13/500
# 798/798 [==============================] - 237s 296ms/step - loss: 0.1598 - acc: 0.9228 - mean_squared_error: 0.0490 - val_loss: 0.1890 - val_acc: 0.9115 - val_mean_squared_error: 0.0588
# Epoch 14/500
# 798/798 [==============================] - 240s 300ms/step - loss: 0.1574 - acc: 0.9238 - mean_squared_error: 0.0484 - val_loss: 0.1891 - val_acc: 0.9118 - val_mean_squared_error: 0.0588
# Epoch 15/500
# 798/798 [==============================] - 234s 294ms/step - loss: 0.1550 - acc: 0.9244 - mean_squared_error: 0.0478 - val_loss: 0.1923 - val_acc: 0.9120 - val_mean_squared_error: 0.0595
# Epoch 16/500
# 798/798 [==============================] - 251s 315ms/step - loss: 0.1530 - acc: 0.9254 - mean_squared_error: 0.0472 - val_loss: 0.1963 - val_acc: 0.9123 - val_mean_squared_error: 0.0601
# Epoch 17/500
# 798/798 [==============================] - 233s 292ms/step - loss: 0.1508 - acc: 0.9272 - mean_squared_error: 0.0465 - val_loss: 0.2024 - val_acc: 0.9124 - val_mean_squared_error: 0.0610
# Epoch 18/500
# 798/798 [==============================] - 249s 313ms/step - loss: 0.1502 - acc: 0.9268 - mean_squared_error: 0.0464 - val_loss: 0.2013 - val_acc: 0.9132 - val_mean_squared_error: 0.0604
# Epoch 19/500
# 798/798 [==============================] - 233s 292ms/step - loss: 0.1491 - acc: 0.9276 - mean_squared_error: 0.0461 - val_loss: 0.2009 - val_acc: 0.9136 - val_mean_squared_error: 0.0602
# Epoch 20/500
# 798/798 [==============================] - 252s 315ms/step - loss: 0.1478 - acc: 0.9280 - mean_squared_error: 0.0456 - val_loss: 0.2010 - val_acc: 0.9137 - val_mean_squared_error: 0.0602
# Epoch 21/500
# 798/798 [==============================] - 231s 290ms/step - loss: 0.1462 - acc: 0.9298 - mean_squared_error: 0.0451 - val_loss: 0.1985 - val_acc: 0.9142 - val_mean_squared_error: 0.0596
# Epoch 22/500
# 798/798 [==============================] - 250s 313ms/step - loss: 0.1445 - acc: 0.9310 - mean_squared_error: 0.0445 - val_loss: 0.1968 - val_acc: 0.9146 - val_mean_squared_error: 0.0591
# Epoch 23/500
# 798/798 [==============================] - 231s 289ms/step - loss: 0.1438 - acc: 0.9313 - mean_squared_error: 0.0443 - val_loss: 0.1943 - val_acc: 0.9153 - val_mean_squared_error: 0.0584
# Epoch 24/500
# 798/798 [==============================] - 257s 322ms/step - loss: 0.1422 - acc: 0.9329 - mean_squared_error: 0.0438 - val_loss: 0.1921 - val_acc: 0.9159 - val_mean_squared_error: 0.0579
# Epoch 25/500
# 798/798 [==============================] - 229s 286ms/step - loss: 0.1408 - acc: 0.9338 - mean_squared_error: 0.0432 - val_loss: 0.1903 - val_acc: 0.9169 - val_mean_squared_error: 0.0574
# Epoch 26/500
# 798/798 [==============================] - 250s 313ms/step - loss: 0.1393 - acc: 0.9351 - mean_squared_error: 0.0426 - val_loss: 0.1876 - val_acc: 0.9178 - val_mean_squared_error: 0.0568
# Epoch 27/500
# 798/798 [==============================] - 228s 286ms/step - loss: 0.1378 - acc: 0.9367 - mean_squared_error: 0.0421 - val_loss: 0.1858 - val_acc: 0.9184 - val_mean_squared_error: 0.0562
# Epoch 28/500
# 798/798 [==============================] - 252s 316ms/step - loss: 0.1364 - acc: 0.9379 - mean_squared_error: 0.0416 - val_loss: 0.1831 - val_acc: 0.9189 - val_mean_squared_error: 0.0554
# Epoch 29/500
# 798/798 [==============================] - 228s 285ms/step - loss: 0.1329 - acc: 0.9392 - mean_squared_error: 0.0407 - val_loss: 0.1809 - val_acc: 0.9193 - val_mean_squared_error: 0.0549
# Epoch 30/500
# 798/798 [==============================] - 260s 325ms/step - loss: 0.1330 - acc: 0.9405 - mean_squared_error: 0.0403 - val_loss: 0.1800 - val_acc: 0.9189 - val_mean_squared_error: 0.0548
# Epoch 31/500
# 798/798 [==============================] - 224s 280ms/step - loss: 0.1316 - acc: 0.9423 - mean_squared_error: 0.0398 - val_loss: 0.1787 - val_acc: 0.9188 - val_mean_squared_error: 0.0546
# Epoch 32/500
# 798/798 [==============================] - 257s 322ms/step - loss: 0.1296 - acc: 0.9432 - mean_squared_error: 0.0391 - val_loss: 0.1778 - val_acc: 0.9184 - val_mean_squared_error: 0.0545
# Epoch 33/500
# 798/798 [==============================] - 223s 280ms/step - loss: 0.1283 - acc: 0.9443 - mean_squared_error: 0.0385 - val_loss: 0.1774 - val_acc: 0.9171 - val_mean_squared_error: 0.0547
# Epoch 34/500
# 798/798 [==============================] - 257s 322ms/step - loss: 0.1265 - acc: 0.9460 - mean_squared_error: 0.0379 - val_loss: 0.1756 - val_acc: 0.9173 - val_mean_squared_error: 0.0543
# Epoch 35/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1249 - acc: 0.9468 - mean_squared_error: 0.0373 - val_loss: 0.1759 - val_acc: 0.9161 - val_mean_squared_error: 0.0547
# Epoch 36/500
# 798/798 [==============================] - 262s 329ms/step - loss: 0.1234 - acc: 0.9482 - mean_squared_error: 0.0368 - val_loss: 0.1790 - val_acc: 0.9140 - val_mean_squared_error: 0.0558
# Epoch 37/500
# 798/798 [==============================] - 224s 280ms/step - loss: 0.1215 - acc: 0.9498 - mean_squared_error: 0.0361 - val_loss: 0.1797 - val_acc: 0.9133 - val_mean_squared_error: 0.0562
# Epoch 38/500
# 798/798 [==============================] - 259s 324ms/step - loss: 0.1202 - acc: 0.9509 - mean_squared_error: 0.0356 - val_loss: 0.1811 - val_acc: 0.9127 - val_mean_squared_error: 0.0567
# Epoch 39/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1188 - acc: 0.9519 - mean_squared_error: 0.0350 - val_loss: 0.1816 - val_acc: 0.9128 - val_mean_squared_error: 0.0568
# Epoch 40/500
# 798/798 [==============================] - 263s 330ms/step - loss: 0.1167 - acc: 0.9533 - mean_squared_error: 0.0343 - val_loss: 0.1826 - val_acc: 0.9121 - val_mean_squared_error: 0.0573
# Epoch 41/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.1147 - acc: 0.9548 - mean_squared_error: 0.0335 - val_loss: 0.1827 - val_acc: 0.9123 - val_mean_squared_error: 0.0572
# Epoch 42/500
# 798/798 [==============================] - 269s 337ms/step - loss: 0.1137 - acc: 0.9553 - mean_squared_error: 0.0332 - val_loss: 0.1846 - val_acc: 0.9114 - val_mean_squared_error: 0.0580
# Epoch 43/500
# 798/798 [==============================] - 218s 273ms/step - loss: 0.1129 - acc: 0.9563 - mean_squared_error: 0.0328 - val_loss: 0.1864 - val_acc: 0.9105 - val_mean_squared_error: 0.0587
# Epoch 44/500
# 798/798 [==============================] - 270s 338ms/step - loss: 0.1113 - acc: 0.9572 - mean_squared_error: 0.0323 - val_loss: 0.1885 - val_acc: 0.9089 - val_mean_squared_error: 0.0596
# Epoch 45/500
# 798/798 [==============================] - 220s 275ms/step - loss: 0.1098 - acc: 0.9583 - mean_squared_error: 0.0317 - val_loss: 0.1915 - val_acc: 0.9078 - val_mean_squared_error: 0.0606
# Epoch 46/500
# 798/798 [==============================] - 270s 338ms/step - loss: 0.1082 - acc: 0.9591 - mean_squared_error: 0.0312 - val_loss: 0.1933 - val_acc: 0.9070 - val_mean_squared_error: 0.0613
# Epoch 47/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.1066 - acc: 0.9603 - mean_squared_error: 0.0305 - val_loss: 0.1974 - val_acc: 0.9045 - val_mean_squared_error: 0.0629
# Epoch 48/500
# 798/798 [==============================] - 268s 336ms/step - loss: 0.1050 - acc: 0.9609 - mean_squared_error: 0.0300 - val_loss: 0.2018 - val_acc: 0.9022 - val_mean_squared_error: 0.0645
# Epoch 49/500
# 798/798 [==============================] - 221s 276ms/step - loss: 0.1036 - acc: 0.9621 - mean_squared_error: 0.0295 - val_loss: 0.2057 - val_acc: 0.9002 - val_mean_squared_error: 0.0659
# Epoch 50/500
# 798/798 [==============================] - 269s 338ms/step - loss: 0.1018 - acc: 0.9629 - mean_squared_error: 0.0289 - val_loss: 0.2088 - val_acc: 0.8996 - val_mean_squared_error: 0.0668
# Epoch 51/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.1006 - acc: 0.9634 - mean_squared_error: 0.0284 - val_loss: 0.2096 - val_acc: 0.8999 - val_mean_squared_error: 0.0668
# Epoch 52/500
# 798/798 [==============================] - 274s 344ms/step - loss: 0.0998 - acc: 0.9640 - mean_squared_error: 0.0281 - val_loss: 0.2114 - val_acc: 0.8992 - val_mean_squared_error: 0.0674
# Epoch 53/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0983 - acc: 0.9647 - mean_squared_error: 0.0275 - val_loss: 0.2122 - val_acc: 0.8999 - val_mean_squared_error: 0.0673
# Epoch 54/500
# 798/798 [==============================] - 278s 348ms/step - loss: 0.0969 - acc: 0.9657 - mean_squared_error: 0.0271 - val_loss: 0.2142 - val_acc: 0.8993 - val_mean_squared_error: 0.0679
# Epoch 55/500
# 798/798 [==============================] - 219s 275ms/step - loss: 0.0954 - acc: 0.9662 - mean_squared_error: 0.0266 - val_loss: 0.2156 - val_acc: 0.8995 - val_mean_squared_error: 0.0682
# Epoch 56/500
# 798/798 [==============================] - 275s 344ms/step - loss: 0.0941 - acc: 0.9671 - mean_squared_error: 0.0261 - val_loss: 0.2146 - val_acc: 0.9007 - val_mean_squared_error: 0.0677
# Epoch 57/500
# 798/798 [==============================] - 217s 272ms/step - loss: 0.0926 - acc: 0.9676 - mean_squared_error: 0.0257 - val_loss: 0.2183 - val_acc: 0.8996 - val_mean_squared_error: 0.0687
# Epoch 58/500
# 798/798 [==============================] - 272s 341ms/step - loss: 0.0914 - acc: 0.9684 - mean_squared_error: 0.0252 - val_loss: 0.2193 - val_acc: 0.8998 - val_mean_squared_error: 0.0688
# Epoch 59/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0903 - acc: 0.9687 - mean_squared_error: 0.0248 - val_loss: 0.2195 - val_acc: 0.9004 - val_mean_squared_error: 0.0686
# Epoch 60/500
# 798/798 [==============================] - 270s 339ms/step - loss: 0.0887 - acc: 0.9696 - mean_squared_error: 0.0243 - val_loss: 0.2219 - val_acc: 0.9002 - val_mean_squared_error: 0.0691
# Epoch 61/500
# 798/798 [==============================] - 219s 275ms/step - loss: 0.0876 - acc: 0.9703 - mean_squared_error: 0.0238 - val_loss: 0.2226 - val_acc: 0.9005 - val_mean_squared_error: 0.0691
# Epoch 62/500
# 798/798 [==============================] - 266s 333ms/step - loss: 0.0861 - acc: 0.9707 - mean_squared_error: 0.0234 - val_loss: 0.2239 - val_acc: 0.9004 - val_mean_squared_error: 0.0694
# Epoch 63/500
# 798/798 [==============================] - 219s 275ms/step - loss: 0.0847 - acc: 0.9716 - mean_squared_error: 0.0229 - val_loss: 0.2234 - val_acc: 0.9018 - val_mean_squared_error: 0.0689
# Epoch 64/500
# 798/798 [==============================] - 271s 339ms/step - loss: 0.0835 - acc: 0.9721 - mean_squared_error: 0.0226 - val_loss: 0.2262 - val_acc: 0.9010 - val_mean_squared_error: 0.0696
# Epoch 65/500
# 798/798 [==============================] - 219s 274ms/step - loss: 0.0823 - acc: 0.9726 - mean_squared_error: 0.0221 - val_loss: 0.2261 - val_acc: 0.9017 - val_mean_squared_error: 0.0693
# Epoch 66/500
# 798/798 [==============================] - 272s 341ms/step - loss: 0.0810 - acc: 0.9733 - mean_squared_error: 0.0217 - val_loss: 0.2254 - val_acc: 0.9024 - val_mean_squared_error: 0.0689
# Epoch 67/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0796 - acc: 0.9739 - mean_squared_error: 0.0213 - val_loss: 0.2260 - val_acc: 0.9026 - val_mean_squared_error: 0.0688
# Epoch 68/500
# 798/798 [==============================] - 267s 335ms/step - loss: 0.0783 - acc: 0.9744 - mean_squared_error: 0.0209 - val_loss: 0.2272 - val_acc: 0.9027 - val_mean_squared_error: 0.0689
# Epoch 69/500
# 798/798 [==============================] - 218s 273ms/step - loss: 0.0772 - acc: 0.9747 - mean_squared_error: 0.0205 - val_loss: 0.2264 - val_acc: 0.9034 - val_mean_squared_error: 0.0685
# Epoch 70/500
# 798/798 [==============================] - 276s 346ms/step - loss: 0.0762 - acc: 0.9754 - mean_squared_error: 0.0201 - val_loss: 0.2286 - val_acc: 0.9036 - val_mean_squared_error: 0.0688
# Epoch 71/500
# 798/798 [==============================] - 217s 273ms/step - loss: 0.0743 - acc: 0.9760 - mean_squared_error: 0.0196 - val_loss: 0.2302 - val_acc: 0.9032 - val_mean_squared_error: 0.0691
# Epoch 72/500
# 798/798 [==============================] - 266s 333ms/step - loss: 0.0738 - acc: 0.9765 - mean_squared_error: 0.0194 - val_loss: 0.2310 - val_acc: 0.9040 - val_mean_squared_error: 0.0689
# Epoch 73/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0725 - acc: 0.9769 - mean_squared_error: 0.0190 - val_loss: 0.2325 - val_acc: 0.9038 - val_mean_squared_error: 0.0691
# Epoch 74/500
# 798/798 [==============================] - 272s 340ms/step - loss: 0.0712 - acc: 0.9774 - mean_squared_error: 0.0186 - val_loss: 0.2326 - val_acc: 0.9042 - val_mean_squared_error: 0.0691
# Epoch 75/500
# 798/798 [==============================] - 221s 277ms/step - loss: 0.0701 - acc: 0.9779 - mean_squared_error: 0.0182 - val_loss: 0.2311 - val_acc: 0.9052 - val_mean_squared_error: 0.0684
# Epoch 76/500
# 798/798 [==============================] - 267s 335ms/step - loss: 0.0689 - acc: 0.9783 - mean_squared_error: 0.0179 - val_loss: 0.2312 - val_acc: 0.9055 - val_mean_squared_error: 0.0683
# Epoch 77/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0679 - acc: 0.9787 - mean_squared_error: 0.0175 - val_loss: 0.2318 - val_acc: 0.9062 - val_mean_squared_error: 0.0681
# Epoch 78/500
# 798/798 [==============================] - 266s 333ms/step - loss: 0.0669 - acc: 0.9791 - mean_squared_error: 0.0172 - val_loss: 0.2302 - val_acc: 0.9068 - val_mean_squared_error: 0.0677
# Epoch 79/500
# 798/798 [==============================] - 220s 276ms/step - loss: 0.0655 - acc: 0.9798 - mean_squared_error: 0.0168 - val_loss: 0.2290 - val_acc: 0.9083 - val_mean_squared_error: 0.0668
# Epoch 80/500
# 798/798 [==============================] - 271s 339ms/step - loss: 0.0647 - acc: 0.9804 - mean_squared_error: 0.0165 - val_loss: 0.2284 - val_acc: 0.9088 - val_mean_squared_error: 0.0666
# Epoch 81/500
# 798/798 [==============================] - 222s 278ms/step - loss: 0.0635 - acc: 0.9805 - mean_squared_error: 0.0162 - val_loss: 0.2332 - val_acc: 0.9077 - val_mean_squared_error: 0.0676
# Epoch 82/500
# 798/798 [==============================] - 267s 335ms/step - loss: 0.0624 - acc: 0.9808 - mean_squared_error: 0.0159 - val_loss: 0.2333 - val_acc: 0.9084 - val_mean_squared_error: 0.0673
# Epoch 83/500
# 798/798 [==============================] - 219s 274ms/step - loss: 0.0616 - acc: 0.9813 - mean_squared_error: 0.0157 - val_loss: 0.2339 - val_acc: 0.9086 - val_mean_squared_error: 0.0673
# Epoch 84/500
# 798/798 [==============================] - 264s 331ms/step - loss: 0.0605 - acc: 0.9815 - mean_squared_error: 0.0153 - val_loss: 0.2351 - val_acc: 0.9091 - val_mean_squared_error: 0.0673
# (146800, 1)
# (146800, 1)
# (147006,)
# CNN:
#
# [[124925   8732]
#  [  4673   8470]] 0.91 0.94
# 19899
#  BASELINE MODEL:
#
# [[133657      0]
#  [ 13143      0]] 0.91 0.5
#
#  RANDOM MODEL:
#
# [[66577 67080]
#  [ 6618  6525]] 0.5 0.5
