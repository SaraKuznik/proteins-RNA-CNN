# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics

import random
random.seed(7)


def generator(X, Y, batch_size=32, train=True):
    while True:
        for offset in range(0, len(X), batch_size):
            X_batch = np.stack(X[offset:offset+batch_size], axis=0)
            
            if train:
                Y_batch = np.stack(Y[offset:offset+batch_size], axis=0)
            
                Y_batch_ = np.array(list(map(np.sum, Y_batch)))
                Y_batch_[Y_batch_ < 100] = 0
                Y_batch_[Y_batch_ >= 100] = 1
                

                Y_f = np.array([Y_batch_[e].flatten() for e in range(Y_batch_.shape[0])])
                yield (X_batch, Y_f)
            
            else:
                yield X_batch

structure_ids = []   
for line in open('./structures lists/stucture ids homo sapiens.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids synthetic construct.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)
for line in open('./structures lists/stucture ids virus.txt', 'r'):
    line = line.strip('\n').lower()
    structure_ids.append(line)

structure_ids.remove('1a9n')
structure_ids.remove('2adc')
random.shuffle(structure_ids)
print(len(structure_ids))

num_test = int(len(structure_ids)*0.3)

X_train = []
X_test = []
Y_train = []
Y_test = []
num_aa_train = 0
num_aa_test = 0
for j, structure_id in enumerate(structure_ids):
    protein = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_protein.npy')
    rna = np.load('../data/voxelized data 14x14x17 2/' + structure_id + '_rna_3D.npy')

    if j <= num_test:
        X_test.extend(protein[:, :, :, :, :3])
        Y_test.extend(rna)
        num_aa_test +=len(rna)
        

    else:
        X_train.extend(protein[:, :, :, :, :3])
        Y_train.extend(rna)
        num_aa_train +=len(rna)



Y_test = np.stack(Y_test, axis=0)
Y_test_ = np.array(list(map(np.sum, Y_test)))
Y_test_[Y_test_ < 100] = 0
Y_test_[Y_test_ >= 100] = 1


print(Y_test.shape)

n_steps_train = int(num_aa_train/1024) 
n_steps_test = int(num_aa_test/1024)

print(num_aa_train, num_aa_test)


generator_train = generator(X_train, Y_train, 1024, True)
generator_validation = generator(X_test, Y_test, 1024, True)
generator_test = generator(X_test, Y_test, 1024, False)

ins = tf.keras.layers.Input((14, 14, 17, 3))
con1 = tf.keras.layers.Conv3D(filters=64, kernel_size=(3, 3, 3), padding='same', activation='relu')(ins)
con2 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con1)
con3 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(con2)
maxp1 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con3)
con4 = tf.keras.layers.Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp1)
con5 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con4)
con6 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(con5)
maxp2 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con6)
con7 = tf.keras.layers.Conv3D(filters=16, kernel_size=(3, 3, 3), padding='same', activation='relu')(maxp2)
con8 = tf.keras.layers.Conv3D(filters=8, kernel_size=(3, 3, 3), padding='same', activation='relu')(con7)
con9 = tf.keras.layers.Conv3D(filters=4, kernel_size=(3, 3, 3), padding='same', activation='relu')(con8)
maxp3 = tf.keras.layers.MaxPool3D(pool_size=(2, 2, 2))(con9)
batch = tf.keras.layers.BatchNormalization()(maxp3)
flat = tf.keras.layers.Flatten()(batch)
dens2 = tf.keras.layers.Dense(units=256, activation='relu')(flat)
drop2 = tf.keras.layers.Dropout(0.6)(dens2)
outs = tf.keras.layers.Dense(units=1, activation='sigmoid')(drop2)
model = tf.keras.models.Model(inputs=ins, outputs=outs)
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.00001), metrics=['accuracy', 'mse'])

model.summary()

# checkpoint
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, mode='min', min_delta=0.0001)
# mc = tf.keras.callbacks.ModelCheckpoint("weights_best.hdf5", monitor='val_loss', verbose=0, save_best_only=True, mode='min')

# model.fit(X_train, Y_train_f, validation_split=0.33, epochs=1, batch_size=200, callbacks=callbacks_list, verbose=0)
history = model.fit_generator(generator_train, steps_per_epoch=n_steps_train, epochs=500, 
                    validation_data = generator_validation, validation_steps=n_steps_test, callbacks=[es], verbose=1)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_new')
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_new')


# model_best = model
# model_best.load_weights("weights_best.hdf5")
# print(model.evaluate(X_test, Y_test, verbose=0, batch_size=100))
# model_best.save('model_cnn_15_2.h5')
# Y_pred = model_best.predict(X_test, batch_size=200)
Y_pred_ = model.predict_generator(generator_test, steps=n_steps_test)
print(Y_pred_.shape)


#CNN
Y_pred_prob = Y_pred_
Y_pred_[Y_pred_ >= 0.5] = 1
Y_pred_[Y_pred_ < 0.5] = 0

print(Y_pred_.shape)
print(Y_test_.shape)
Y_test_ = Y_test_[:Y_pred_.shape[0]]


print('CNN: \n')
confusion_matrix = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_)
accuracy = np.sum(np.trace(confusion_matrix))/np.sum(confusion_matrix)
auc = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_prob)

print(confusion_matrix, np.round(accuracy, 2), np.round(auc, 2))

# baseline model
# predict all zeros; at least 50% correct predictions because there are 1/2 of negative examples
Y_pred_base = np.zeros(Y_test_.shape)

# po = np.sum(Y_train, axis=0)/Y_train.shape[0]
# po[po >= 0.5] = 1
# po[po < 0.5] = 0
# Y_pred_base = np.tile(po, (Y_test.shape[0],1))

print(f'\n BASELINE MODEL: \n')
confusion_matrix_base = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_base)
accuracy_base = np.sum(np.trace(confusion_matrix_base))/np.sum(confusion_matrix_base)
auc_base = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_base)

print(confusion_matrix_base, np.round(accuracy_base, 2), np.round(auc_base, 2))

#random model
Y_pred_random = np.random.random(Y_test_.shape)
Y_pred_random[Y_pred_random >= 0.5] = 1
Y_pred_random[Y_pred_random < 0.5] = 0

print(f'\n RANDOM MODEL: \n')
confusion_matrix_random = sklearn.metrics.confusion_matrix(Y_test_, Y_pred_random)
accuracy_random = np.sum(np.trace(confusion_matrix_random))/np.sum(confusion_matrix_random)
auc_random = sklearn.metrics.roc_auc_score(Y_test_, Y_pred_random)

print(confusion_matrix_random, np.round(accuracy_random, 2), np.round(auc_random, 2))
# Out:
# 549
# WARNING: Logging before flag parsing goes to stderr.
# W0828 19:23:57.924280 139920021337856 deprecation.py:506] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# (147006, 14, 14, 17)
# 319356 147006
# W0828 19:23:58.234419 139920021337856 nn_ops.py:4224] Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0828 19:23:58.300940 139920021337856 deprecation.py:323] From /home/skuznik/local/miniconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 14, 14, 17, 3)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 14, 14, 17, 64)    5248
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 14, 14, 17, 32)    55328
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 14, 14, 17, 32)    27680
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 7, 8, 32)       0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 7, 8, 32)       27680
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 8, 16)       13840
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 7, 7, 8, 16)       6928
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 3, 4, 16)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 3, 3, 4, 16)       6928
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 3, 4, 8)        3464
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 3, 4, 4)        868
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 1, 2, 4)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 2, 4)        16
# _________________________________________________________________
# flatten (Flatten)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 150,541
# Trainable params: 150,533
# Non-trainable params: 8
# _________________________________________________________________
# Epoch 1/500
# 311/311 [==============================] - 300s 963ms/step - loss: 0.6791 - acc: 0.7888 - mean_squared_error: 0.2430 - val_loss: 0.6718 - val_acc: 0.8967 - val_mean_squared_error: 0.2393
# Epoch 2/500
# 311/311 [==============================] - 299s 961ms/step - loss: 0.5891 - acc: 0.8781 - mean_squared_error: 0.1987 - val_loss: 0.5994 - val_acc: 0.9109 - val_mean_squared_error: 0.2035
# Epoch 3/500
# 311/311 [==============================] - 296s 952ms/step - loss: 0.5086 - acc: 0.9150 - mean_squared_error: 0.1605 - val_loss: 0.5529 - val_acc: 0.9147 - val_mean_squared_error: 0.1807
# Epoch 4/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.4504 - acc: 0.9228 - mean_squared_error: 0.1343 - val_loss: 0.5149 - val_acc: 0.9100 - val_mean_squared_error: 0.1626
# Epoch 5/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.4023 - acc: 0.9232 - mean_squared_error: 0.1141 - val_loss: 0.4657 - val_acc: 0.9100 - val_mean_squared_error: 0.1403
# Epoch 6/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.3536 - acc: 0.9227 - mean_squared_error: 0.0954 - val_loss: 0.3675 - val_acc: 0.9100 - val_mean_squared_error: 0.1004
# Epoch 7/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.3132 - acc: 0.9246 - mean_squared_error: 0.0814 - val_loss: 0.3120 - val_acc: 0.9099 - val_mean_squared_error: 0.0822
# Epoch 8/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.2865 - acc: 0.9235 - mean_squared_error: 0.0735 - val_loss: 0.2855 - val_acc: 0.9101 - val_mean_squared_error: 0.0749
# Epoch 9/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.2640 - acc: 0.9244 - mean_squared_error: 0.0672 - val_loss: 0.2602 - val_acc: 0.9136 - val_mean_squared_error: 0.0681
# Epoch 10/500
# 311/311 [==============================] - 286s 920ms/step - loss: 0.2464 - acc: 0.9243 - mean_squared_error: 0.0628 - val_loss: 0.2473 - val_acc: 0.9108 - val_mean_squared_error: 0.0663
# Epoch 11/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.2321 - acc: 0.9247 - mean_squared_error: 0.0596 - val_loss: 0.2302 - val_acc: 0.9126 - val_mean_squared_error: 0.0623
# Epoch 12/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.2193 - acc: 0.9257 - mean_squared_error: 0.0568 - val_loss: 0.2242 - val_acc: 0.9107 - val_mean_squared_error: 0.0621
# Epoch 13/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.2092 - acc: 0.9259 - mean_squared_error: 0.0549 - val_loss: 0.2176 - val_acc: 0.9108 - val_mean_squared_error: 0.0611
# Epoch 14/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.2002 - acc: 0.9263 - mean_squared_error: 0.0532 - val_loss: 0.2123 - val_acc: 0.9106 - val_mean_squared_error: 0.0603
# Epoch 15/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1931 - acc: 0.9271 - mean_squared_error: 0.0520 - val_loss: 0.2077 - val_acc: 0.9102 - val_mean_squared_error: 0.0597
# Epoch 16/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1853 - acc: 0.9293 - mean_squared_error: 0.0503 - val_loss: 0.2034 - val_acc: 0.9099 - val_mean_squared_error: 0.0593
# Epoch 17/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1819 - acc: 0.9288 - mean_squared_error: 0.0501 - val_loss: 0.2002 - val_acc: 0.9096 - val_mean_squared_error: 0.0589
# Epoch 18/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.1778 - acc: 0.9286 - mean_squared_error: 0.0497 - val_loss: 0.1977 - val_acc: 0.9093 - val_mean_squared_error: 0.0586
# Epoch 19/500
# 311/311 [==============================] - 295s 947ms/step - loss: 0.1722 - acc: 0.9291 - mean_squared_error: 0.0486 - val_loss: 0.1919 - val_acc: 0.9104 - val_mean_squared_error: 0.0571
# Epoch 20/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1681 - acc: 0.9310 - mean_squared_error: 0.0477 - val_loss: 0.1922 - val_acc: 0.9096 - val_mean_squared_error: 0.0577
# Epoch 21/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1666 - acc: 0.9304 - mean_squared_error: 0.0478 - val_loss: 0.1914 - val_acc: 0.9089 - val_mean_squared_error: 0.0578
# Epoch 22/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1639 - acc: 0.9308 - mean_squared_error: 0.0474 - val_loss: 0.1895 - val_acc: 0.9098 - val_mean_squared_error: 0.0575
# Epoch 23/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1610 - acc: 0.9314 - mean_squared_error: 0.0468 - val_loss: 0.1874 - val_acc: 0.9106 - val_mean_squared_error: 0.0571
# Epoch 24/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1588 - acc: 0.9320 - mean_squared_error: 0.0465 - val_loss: 0.1858 - val_acc: 0.9112 - val_mean_squared_error: 0.0567
# Epoch 25/500
# 311/311 [==============================] - 296s 952ms/step - loss: 0.1564 - acc: 0.9330 - mean_squared_error: 0.0459 - val_loss: 0.1792 - val_acc: 0.9145 - val_mean_squared_error: 0.0545
# Epoch 26/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1542 - acc: 0.9336 - mean_squared_error: 0.0454 - val_loss: 0.1830 - val_acc: 0.9119 - val_mean_squared_error: 0.0563
# Epoch 27/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1524 - acc: 0.9339 - mean_squared_error: 0.0451 - val_loss: 0.1820 - val_acc: 0.9122 - val_mean_squared_error: 0.0560
# Epoch 28/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1508 - acc: 0.9343 - mean_squared_error: 0.0447 - val_loss: 0.1812 - val_acc: 0.9123 - val_mean_squared_error: 0.0559
# Epoch 29/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1494 - acc: 0.9354 - mean_squared_error: 0.0444 - val_loss: 0.1804 - val_acc: 0.9126 - val_mean_squared_error: 0.0558
# Epoch 30/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1478 - acc: 0.9361 - mean_squared_error: 0.0440 - val_loss: 0.1795 - val_acc: 0.9129 - val_mean_squared_error: 0.0556
# Epoch 31/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1463 - acc: 0.9368 - mean_squared_error: 0.0436 - val_loss: 0.1792 - val_acc: 0.9127 - val_mean_squared_error: 0.0555
# Epoch 32/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1448 - acc: 0.9376 - mean_squared_error: 0.0432 - val_loss: 0.1756 - val_acc: 0.9146 - val_mean_squared_error: 0.0544
# Epoch 33/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1436 - acc: 0.9381 - mean_squared_error: 0.0429 - val_loss: 0.1780 - val_acc: 0.9135 - val_mean_squared_error: 0.0552
# Epoch 34/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1424 - acc: 0.9386 - mean_squared_error: 0.0426 - val_loss: 0.1770 - val_acc: 0.9141 - val_mean_squared_error: 0.0549
# Epoch 35/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1414 - acc: 0.9390 - mean_squared_error: 0.0423 - val_loss: 0.1766 - val_acc: 0.9143 - val_mean_squared_error: 0.0548
# Epoch 36/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1400 - acc: 0.9401 - mean_squared_error: 0.0419 - val_loss: 0.1765 - val_acc: 0.9142 - val_mean_squared_error: 0.0548
# Epoch 37/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1385 - acc: 0.9404 - mean_squared_error: 0.0414 - val_loss: 0.1721 - val_acc: 0.9164 - val_mean_squared_error: 0.0533
# Epoch 38/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1368 - acc: 0.9416 - mean_squared_error: 0.0409 - val_loss: 0.1728 - val_acc: 0.9163 - val_mean_squared_error: 0.0538
# Epoch 39/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1344 - acc: 0.9435 - mean_squared_error: 0.0400 - val_loss: 0.1683 - val_acc: 0.9193 - val_mean_squared_error: 0.0522
# Epoch 40/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1356 - acc: 0.9427 - mean_squared_error: 0.0404 - val_loss: 0.1750 - val_acc: 0.9153 - val_mean_squared_error: 0.0546
# Epoch 41/500
# 311/311 [==============================] - 294s 946ms/step - loss: 0.1346 - acc: 0.9427 - mean_squared_error: 0.0401 - val_loss: 0.1740 - val_acc: 0.9162 - val_mean_squared_error: 0.0543
# Epoch 42/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1336 - acc: 0.9436 - mean_squared_error: 0.0398 - val_loss: 0.1745 - val_acc: 0.9159 - val_mean_squared_error: 0.0545
# Epoch 43/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1327 - acc: 0.9439 - mean_squared_error: 0.0395 - val_loss: 0.1743 - val_acc: 0.9163 - val_mean_squared_error: 0.0545
# Epoch 44/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1316 - acc: 0.9446 - mean_squared_error: 0.0392 - val_loss: 0.1743 - val_acc: 0.9162 - val_mean_squared_error: 0.0545
# Epoch 45/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.1308 - acc: 0.9452 - mean_squared_error: 0.0389 - val_loss: 0.1715 - val_acc: 0.9175 - val_mean_squared_error: 0.0538
# Epoch 46/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1300 - acc: 0.9456 - mean_squared_error: 0.0386 - val_loss: 0.1738 - val_acc: 0.9169 - val_mean_squared_error: 0.0544
# Epoch 47/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1292 - acc: 0.9460 - mean_squared_error: 0.0384 - val_loss: 0.1723 - val_acc: 0.9176 - val_mean_squared_error: 0.0538
# Epoch 48/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1281 - acc: 0.9465 - mean_squared_error: 0.0380 - val_loss: 0.1707 - val_acc: 0.9185 - val_mean_squared_error: 0.0533
# Epoch 49/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1275 - acc: 0.9467 - mean_squared_error: 0.0378 - val_loss: 0.1708 - val_acc: 0.9185 - val_mean_squared_error: 0.0533
# Epoch 50/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1266 - acc: 0.9475 - mean_squared_error: 0.0374 - val_loss: 0.1735 - val_acc: 0.9173 - val_mean_squared_error: 0.0543
# Epoch 51/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1257 - acc: 0.9482 - mean_squared_error: 0.0371 - val_loss: 0.1734 - val_acc: 0.9174 - val_mean_squared_error: 0.0543
# Epoch 52/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1248 - acc: 0.9486 - mean_squared_error: 0.0368 - val_loss: 0.1731 - val_acc: 0.9176 - val_mean_squared_error: 0.0542
# Epoch 53/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1240 - acc: 0.9494 - mean_squared_error: 0.0365 - val_loss: 0.1732 - val_acc: 0.9177 - val_mean_squared_error: 0.0542
# Epoch 54/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1233 - acc: 0.9493 - mean_squared_error: 0.0363 - val_loss: 0.1731 - val_acc: 0.9177 - val_mean_squared_error: 0.0542
# Epoch 55/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1226 - acc: 0.9499 - mean_squared_error: 0.0361 - val_loss: 0.1734 - val_acc: 0.9175 - val_mean_squared_error: 0.0543
# Epoch 56/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1216 - acc: 0.9506 - mean_squared_error: 0.0358 - val_loss: 0.1734 - val_acc: 0.9177 - val_mean_squared_error: 0.0543
# Epoch 57/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.1209 - acc: 0.9506 - mean_squared_error: 0.0355 - val_loss: 0.1736 - val_acc: 0.9174 - val_mean_squared_error: 0.0544
# Epoch 58/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1202 - acc: 0.9512 - mean_squared_error: 0.0353 - val_loss: 0.1681 - val_acc: 0.9207 - val_mean_squared_error: 0.0524
# Epoch 59/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1196 - acc: 0.9515 - mean_squared_error: 0.0351 - val_loss: 0.1735 - val_acc: 0.9175 - val_mean_squared_error: 0.0544
# Epoch 60/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1189 - acc: 0.9523 - mean_squared_error: 0.0348 - val_loss: 0.1737 - val_acc: 0.9177 - val_mean_squared_error: 0.0545
# Epoch 61/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1182 - acc: 0.9523 - mean_squared_error: 0.0346 - val_loss: 0.1739 - val_acc: 0.9176 - val_mean_squared_error: 0.0545
# Epoch 62/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1173 - acc: 0.9531 - mean_squared_error: 0.0342 - val_loss: 0.1741 - val_acc: 0.9178 - val_mean_squared_error: 0.0545
# Epoch 63/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1166 - acc: 0.9535 - mean_squared_error: 0.0340 - val_loss: 0.1739 - val_acc: 0.9176 - val_mean_squared_error: 0.0545
# Epoch 64/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1161 - acc: 0.9536 - mean_squared_error: 0.0339 - val_loss: 0.1707 - val_acc: 0.9184 - val_mean_squared_error: 0.0538
# Epoch 65/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1152 - acc: 0.9542 - mean_squared_error: 0.0336 - val_loss: 0.1721 - val_acc: 0.9181 - val_mean_squared_error: 0.0541
# Epoch 66/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1148 - acc: 0.9546 - mean_squared_error: 0.0334 - val_loss: 0.1710 - val_acc: 0.9194 - val_mean_squared_error: 0.0536
# Epoch 67/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1140 - acc: 0.9549 - mean_squared_error: 0.0331 - val_loss: 0.1707 - val_acc: 0.9193 - val_mean_squared_error: 0.0535
# Epoch 68/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1130 - acc: 0.9553 - mean_squared_error: 0.0328 - val_loss: 0.1730 - val_acc: 0.9181 - val_mean_squared_error: 0.0542
# Epoch 69/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1128 - acc: 0.9554 - mean_squared_error: 0.0327 - val_loss: 0.1757 - val_acc: 0.9169 - val_mean_squared_error: 0.0551
# Epoch 70/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1118 - acc: 0.9560 - mean_squared_error: 0.0324 - val_loss: 0.1758 - val_acc: 0.9170 - val_mean_squared_error: 0.0552
# Epoch 71/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1109 - acc: 0.9565 - mean_squared_error: 0.0321 - val_loss: 0.1763 - val_acc: 0.9168 - val_mean_squared_error: 0.0553
# Epoch 72/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1105 - acc: 0.9563 - mean_squared_error: 0.0320 - val_loss: 0.1761 - val_acc: 0.9169 - val_mean_squared_error: 0.0553
# Epoch 73/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1096 - acc: 0.9573 - mean_squared_error: 0.0317 - val_loss: 0.1766 - val_acc: 0.9168 - val_mean_squared_error: 0.0553
# Epoch 74/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1091 - acc: 0.9575 - mean_squared_error: 0.0315 - val_loss: 0.1760 - val_acc: 0.9171 - val_mean_squared_error: 0.0552
# Epoch 75/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1085 - acc: 0.9577 - mean_squared_error: 0.0313 - val_loss: 0.1720 - val_acc: 0.9194 - val_mean_squared_error: 0.0538
# Epoch 76/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1077 - acc: 0.9583 - mean_squared_error: 0.0310 - val_loss: 0.1768 - val_acc: 0.9167 - val_mean_squared_error: 0.0556
# Epoch 77/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1071 - acc: 0.9585 - mean_squared_error: 0.0308 - val_loss: 0.1783 - val_acc: 0.9161 - val_mean_squared_error: 0.0561
# Epoch 78/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1063 - acc: 0.9591 - mean_squared_error: 0.0305 - val_loss: 0.1781 - val_acc: 0.9161 - val_mean_squared_error: 0.0560
# Epoch 79/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1060 - acc: 0.9589 - mean_squared_error: 0.0304 - val_loss: 0.1793 - val_acc: 0.9155 - val_mean_squared_error: 0.0564
# Epoch 80/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1054 - acc: 0.9594 - mean_squared_error: 0.0302 - val_loss: 0.1802 - val_acc: 0.9148 - val_mean_squared_error: 0.0568
# Epoch 81/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1043 - acc: 0.9602 - mean_squared_error: 0.0299 - val_loss: 0.1745 - val_acc: 0.9177 - val_mean_squared_error: 0.0549
# Epoch 82/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1023 - acc: 0.9610 - mean_squared_error: 0.0292 - val_loss: 0.1836 - val_acc: 0.9138 - val_mean_squared_error: 0.0578
# Epoch 83/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.1033 - acc: 0.9606 - mean_squared_error: 0.0295 - val_loss: 0.1771 - val_acc: 0.9171 - val_mean_squared_error: 0.0556
# Epoch 84/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.1027 - acc: 0.9610 - mean_squared_error: 0.0293 - val_loss: 0.1857 - val_acc: 0.9133 - val_mean_squared_error: 0.0584
# Epoch 85/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1018 - acc: 0.9611 - mean_squared_error: 0.0290 - val_loss: 0.1873 - val_acc: 0.9126 - val_mean_squared_error: 0.0589
# Epoch 86/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1002 - acc: 0.9621 - mean_squared_error: 0.0285 - val_loss: 0.1887 - val_acc: 0.9126 - val_mean_squared_error: 0.0592
# Epoch 87/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.1009 - acc: 0.9619 - mean_squared_error: 0.0287 - val_loss: 0.1885 - val_acc: 0.9130 - val_mean_squared_error: 0.0590
# Epoch 88/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.1002 - acc: 0.9620 - mean_squared_error: 0.0285 - val_loss: 0.1890 - val_acc: 0.9136 - val_mean_squared_error: 0.0590
# Epoch 89/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0994 - acc: 0.9625 - mean_squared_error: 0.0282 - val_loss: 0.1898 - val_acc: 0.9138 - val_mean_squared_error: 0.0591
# Epoch 90/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0986 - acc: 0.9630 - mean_squared_error: 0.0280 - val_loss: 0.1916 - val_acc: 0.9141 - val_mean_squared_error: 0.0593
# Epoch 91/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0970 - acc: 0.9639 - mean_squared_error: 0.0274 - val_loss: 0.1872 - val_acc: 0.9173 - val_mean_squared_error: 0.0575
# Epoch 92/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0969 - acc: 0.9635 - mean_squared_error: 0.0274 - val_loss: 0.1911 - val_acc: 0.9156 - val_mean_squared_error: 0.0586
# Epoch 93/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0975 - acc: 0.9637 - mean_squared_error: 0.0275 - val_loss: 0.1920 - val_acc: 0.9155 - val_mean_squared_error: 0.0588
# Epoch 94/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.0970 - acc: 0.9639 - mean_squared_error: 0.0273 - val_loss: 0.1922 - val_acc: 0.9155 - val_mean_squared_error: 0.0589
# Epoch 95/500
# 311/311 [==============================] - 296s 950ms/step - loss: 0.0965 - acc: 0.9640 - mean_squared_error: 0.0272 - val_loss: 0.1928 - val_acc: 0.9156 - val_mean_squared_error: 0.0590
# Epoch 96/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.0958 - acc: 0.9644 - mean_squared_error: 0.0270 - val_loss: 0.1932 - val_acc: 0.9157 - val_mean_squared_error: 0.0589
# Epoch 97/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.0950 - acc: 0.9646 - mean_squared_error: 0.0267 - val_loss: 0.1840 - val_acc: 0.9190 - val_mean_squared_error: 0.0564
# Epoch 98/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.0946 - acc: 0.9652 - mean_squared_error: 0.0265 - val_loss: 0.1928 - val_acc: 0.9159 - val_mean_squared_error: 0.0588
# Epoch 99/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.0939 - acc: 0.9653 - mean_squared_error: 0.0263 - val_loss: 0.1930 - val_acc: 0.9157 - val_mean_squared_error: 0.0589
# Epoch 100/500
# 311/311 [==============================] - 295s 948ms/step - loss: 0.0934 - acc: 0.9656 - mean_squared_error: 0.0261 - val_loss: 0.1930 - val_acc: 0.9158 - val_mean_squared_error: 0.0589
# Epoch 101/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0930 - acc: 0.9660 - mean_squared_error: 0.0260 - val_loss: 0.1935 - val_acc: 0.9157 - val_mean_squared_error: 0.0589
# Epoch 102/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.0922 - acc: 0.9660 - mean_squared_error: 0.0258 - val_loss: 0.1934 - val_acc: 0.9158 - val_mean_squared_error: 0.0589
# Epoch 103/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.0919 - acc: 0.9662 - mean_squared_error: 0.0257 - val_loss: 0.1940 - val_acc: 0.9157 - val_mean_squared_error: 0.0590
# Epoch 104/500
# 311/311 [==============================] - 295s 950ms/step - loss: 0.0916 - acc: 0.9668 - mean_squared_error: 0.0256 - val_loss: 0.1895 - val_acc: 0.9179 - val_mean_squared_error: 0.0575
# Epoch 105/500
# 311/311 [==============================] - 295s 949ms/step - loss: 0.0910 - acc: 0.9669 - mean_squared_error: 0.0254 - val_loss: 0.1939 - val_acc: 0.9158 - val_mean_squared_error: 0.0590
# Epoch 106/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.0900 - acc: 0.9673 - mean_squared_error: 0.0251 - val_loss: 0.1935 - val_acc: 0.9162 - val_mean_squared_error: 0.0589
# Epoch 107/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.0894 - acc: 0.9676 - mean_squared_error: 0.0249 - val_loss: 0.1941 - val_acc: 0.9161 - val_mean_squared_error: 0.0590
# Epoch 108/500
# 311/311 [==============================] - 296s 951ms/step - loss: 0.0893 - acc: 0.9676 - mean_squared_error: 0.0248 - val_loss: 0.1937 - val_acc: 0.9158 - val_mean_squared_error: 0.0590
# (146432, 1)
# (146432, 1)
# (147006,)
# CNN:
#
# [[126639   6650]
#  [  5644   7499]] 0.92 0.76
#
#  BASELINE MODEL:
#
# [[133289      0]
#  [ 13143      0]] 0.91 0.5
#
#  RANDOM MODEL:
#
# [[66346 66943]
#  [ 6487  6656]] 0.5 0.5
